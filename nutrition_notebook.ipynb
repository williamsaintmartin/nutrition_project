# %% [markdown]
# <h1 style = "text-align: center;"><strong>NUTRITION NOTEBOOK</strong></h1>

# %% [markdown]
# ---
# <h2 style = "text-align: center;"><em>State the Problem</em></h2>

# %% [markdown]
# <h3 style = "text-align: center;">"5W1H" Method</h3>

# %% [markdown]
# I want to analyse food contents, to create healthy menus.

# %% [markdown]
# ---
# <h2 style = "text-align: center;"><em>Prepare the Tools</em></h2>

# %% [markdown]
# <h3 style = "text-align: center;">Resources</h3>

# %% [markdown]
# <ul>
#     <li>Domain Documentation
#         <ul>
#             <li><a href="https://en.wikipedia.org/wiki/Statistics">Wikipedia: Nutrition</a></li>
#         </ul>
#     </li>
#     <br>
#     <li>Data Documentation
#         <ul>
#             <li><a href="https://www.data.gouv.fr/fr/datasets/table-de-composition-nutritionnelle-des-aliments-ciqual/">Data.gouv: Ciqual Table Information</a></li>
#             <li><a href="https://ciqual.anses.fr/#/cms/download/node/20">Ciqual.anses: Ciqual Table Download Page</a></li>
#         </ul>
#     </li>
#     <br>
#     <li>Technical Documentation
#         <ul>
#             <li><a href="https://pandas.pydata.org/docs/">Pandas</a></li>
#             <li><a href="https://dev.mysql.com/doc/">MySQL</a></li>
#         </ul>
#     </li>
# </ul>

# %% [markdown]
# <h3 style = "text-align: center;">Libraries</h3>

# %%
# Import libraries
import os
import pandas as pd

# %% [markdown]
# <h3 style = "text-align: center;">Functions</h3>

# %%
# Define a function to check the directory
def check_directory():
    """
    Purpose:
        Check the current directory and its contents
    Parameters:
        None
    Returns:
        None: This function prints the current directory and its contents to the console
    """
    try:
        current_directory = os.getcwd()
        print("DIRECTORY")
        print(current_directory)
        print()
        print("FILES IN DIRECTORY")
        files = os.listdir(current_directory)
        if files:
            for file in files:
                print(file)
            print()
        else:
            print("Files not found")
            
    except Exception as e:
        print(f"Error: {e}")
        raise


# Define a function to check a dataframe
def check_dataframe(dataframe: pd.DataFrame):
    """
    Purpose:
        Check a DataFrame for general information
    Parameters:
        dataframe (pd.DataFrame): DataFrame to check
    Returns:
        None: This function prints general information to the console
    """
    try:
        print("GENERAL INFORMATION")
        print(dataframe.info())
        print()
        print("FIRST ROWS")
        print(dataframe.head())
        print()
        print("LAST ROWS")
        print(dataframe.tail())
        print()
        print("DUPLICATED ROWS")
        print(f"Count of duplicated rows: {dataframe.duplicated().sum()}")
        print()
        print("MISSING VALUES BY COLUMN")
        print(dataframe.isna().sum().reset_index(name = "missing_values_count").rename(columns = {"index": "column_name"}))
        print()
        print("UNIQUE VALUES BY COLUMN")
        print(dataframe.nunique().reset_index(name = "unique_values_count").rename(columns = {"index": "column_name"}))
        print()
        print("STATISTICS")
        print(dataframe.describe(include = "all"))
        
    except Exception as e:
        print(f"Error: {e}")
        raise


# Convert a dataframe into a file (CSV, JSON, XLS, XML)
def dataframe_to_file(dataframe: pd.DataFrame, filename: str, file_format: str, delimiter: str = ","):
    """
    Purpose: 
        Convert a DataFrame into a specified file format (CSV, JSON, XLS, or XML)
    Parameters:
        dataframe (pd.DataFrame): The DataFrame to convert into a file
        filename (str): The filename for the output file
        file_format (str): The format of the file ("csv", "json", "xls", "xml")
        delimiter (str): The delimiter to use if the file format is CSV
    Returns:
        str: A message confirming the file creation 
        or 
        None: This funciton prints an error message; if the conversion fails
    """

    try:
        if os.path.isfile(filename):
            print( f"Creation of '{filename}' failed")

        if file_format.lower() == "csv":
            dataframe.to_csv(filename, sep = delimiter, index = False)
        
        elif file_format.lower() == "json":
            dataframe.to_json(filename, orient = "records", lines = True)
        
        elif file_format.lower() == "xls" or file_format.lower() == "xlsx":
            dataframe.to_excel(filename, index = False)
        
        elif file_format.lower() == "xml":
            dataframe.to_xml(filename, index = False)
        
        else:
            print("Error: Unsupported file format")

        print(f"Creation of '{filename}' successful")
            
    except Exception as e:
        print(f"Error: {e}")
        raise

# %% [markdown]
# ---
# <h2 style = "text-align: center;"><em>Collect Data</em></h2>

# %% [markdown]
# <h3 style = "text-align: center;">Source(s)</h3>

# %%
# Check the directory        
check_directory()
# Out:
# DIRECTORY
# C:\Users\willi\data_resources\portfolio\nutrition_project
#
# FILES IN DIRECTORY
# .ipynb_checkpoints
# ciqual_table.xls
# nutrition_database_carbohydrates_queries.sql
# nutrition_database_fats_queries.sql
# nutrition_database_macronutrients_queries.sql
# nutrition_database_minerals_queries.sql
# nutrition_database_structure.sql
# nutrition_database_vitamins_queries.sql
# nutrition_notebook.ipynb
# nutrition_notebook_v1.ipynb
# table_ciqual_documentation.pdf

# %%
# Store the data in a dataframe
data_file_path = r"C:\Users\willi\data_resources\portfolio\nutrition_project\ciqual_table.xls"
nutrition_df = pd.read_excel(data_file_path, engine = "xlrd")

# %% [markdown]
# <h3 style = "text-align: center;">Check(s)</h3>

# %%
# Check the dataframe
check_dataframe(nutrition_df)
# Out:
# GENERAL INFORMATION
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3186 entries, 0 to 3185
# Data columns (total 76 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   alim_grp_code                                          3186 non-null   int64
#  1   alim_ssgrp_code                                        3186 non-null   int64
#  2   alim_ssssgrp_code                                      3186 non-null   int64
#  3   alim_grp_nom_fr                                        3141 non-null   object
#  4   alim_ssgrp_nom_fr                                      3141 non-null   object
#  5   alim_ssssgrp_nom_fr                                    3141 non-null   object
#  6   alim_code                                              3186 non-null   int64
#  7   alim_nom_fr                                            3186 non-null   object
#  8   alim_nom_sci                                           270 non-null    object
#  9   Energie, Règlement UE N° 1169/2011 (kJ/100 g)          3169 non-null   object
#  10  Energie, Règlement UE N° 1169/2011 (kcal/100 g)        3169 non-null   object
#  11  Energie, N x facteur Jones, avec fibres  (kJ/100 g)    3169 non-null   object
#  12  Energie, N x facteur Jones, avec fibres  (kcal/100 g)  3169 non-null   object
#  13  Eau (g/100 g)                                          3183 non-null   object
#  14  Protéines, N x facteur de Jones (g/100 g)              3185 non-null   object
#  15  Protéines, N x 6.25 (g/100 g)                          3185 non-null   object
#  16  Glucides (g/100 g)                                     3185 non-null   object
#  17  Lipides (g/100 g)                                      3185 non-null   object
#  18  Sucres (g/100 g)                                       3177 non-null   object
#  19  Fructose (g/100 g)                                     3147 non-null   object
#  20  Galactose (g/100 g)                                    3102 non-null   object
#  21  Glucose (g/100 g)                                      3148 non-null   object
#  22  Lactose (g/100 g)                                      3141 non-null   object
#  23  Maltose (g/100 g)                                      3145 non-null   object
#  24  Saccharose (g/100 g)                                   3148 non-null   object
#  25  Amidon (g/100 g)                                       3150 non-null   object
#  26  Fibres alimentaires (g/100 g)                          3185 non-null   object
#  27  Polyols totaux (g/100 g)                               3174 non-null   object
#  28  Cendres (g/100 g)                                      3180 non-null   object
#  29  Alcool (g/100 g)                                       3185 non-null   object
#  30  Acides organiques (g/100 g)                            3180 non-null   object
#  31  AG saturés (g/100 g)                                   3181 non-null   object
#  32  AG monoinsaturés (g/100 g)                             3177 non-null   object
#  33  AG polyinsaturés (g/100 g)                             3175 non-null   object
#  34  AG 4:0, butyrique (g/100 g)                            3153 non-null   object
#  35  AG 6:0, caproïque (g/100 g)                            3151 non-null   object
#  36  AG 8:0, caprylique (g/100 g)                           3152 non-null   object
#  37  AG 10:0, caprique (g/100 g)                            3153 non-null   object
#  38  AG 12:0, laurique (g/100 g)                            3162 non-null   object
#  39  AG 14:0, myristique (g/100 g)                          3164 non-null   object
#  40  AG 16:0, palmitique (g/100 g)                          3164 non-null   object
#  41  AG 18:0, stéarique (g/100 g)                           3164 non-null   object
#  42  AG 18:1 9c (n-9), oléique (g/100 g)                    3147 non-null   object
#  43  AG 18:2 9c,12c (n-6), linoléique (g/100 g)             3147 non-null   object
#  44  AG 18:3 c9,c12,c15 (n-3), alpha-linolénique (g/100 g)  3150 non-null   object
#  45  AG 20:4 5c,8c,11c,14c (n-6), arachidonique (g/100 g)   3135 non-null   object
#  46  AG 20:5 5c,8c,11c,14c,17c (n-3) EPA (g/100 g)          3151 non-null   object
#  47  AG 22:6 4c,7c,10c,13c,16c,19c (n-3) DHA (g/100 g)      3158 non-null   object
#  48  Cholestérol (mg/100 g)                                 3165 non-null   object
#  49  Sel chlorure de sodium (g/100 g)                       3180 non-null   object
#  50  Calcium (mg/100 g)                                     3176 non-null   object
#  51  Chlorure (mg/100 g)                                    3134 non-null   object
#  52  Cuivre (mg/100 g)                                      3168 non-null   object
#  53  Fer (mg/100 g)                                         3178 non-null   object
#  54  Iode (µg/100 g)                                        3165 non-null   object
#  55  Magnésium (mg/100 g)                                   3174 non-null   object
#  56  Manganèse (mg/100 g)                                   3167 non-null   object
#  57  Phosphore (mg/100 g)                                   3172 non-null   object
#  58  Potassium (mg/100 g)                                   3173 non-null   object
#  59  Sélénium (µg/100 g)                                    3165 non-null   object
#  60  Sodium (mg/100 g)                                      3180 non-null   object
#  61  Zinc (mg/100 g)                                        3175 non-null   object
#  62  Rétinol (µg/100 g)                                     3156 non-null   object
#  63  Beta-Carotène (µg/100 g)                               3158 non-null   object
#  64  Vitamine D (µg/100 g)                                  3155 non-null   object
#  65  Vitamine E (mg/100 g)                                  3168 non-null   object
#  66  Vitamine K1 (µg/100 g)                                 3123 non-null   object
#  67  Vitamine K2 (µg/100 g)                                 3071 non-null   object
#  68  Vitamine C (mg/100 g)                                  3165 non-null   object
#  69  Vitamine B1 ou Thiamine (mg/100 g)                     3172 non-null   object
#  70  Vitamine B2 ou Riboflavine (mg/100 g)                  3170 non-null   object
#  71  Vitamine B3 ou PP ou Niacine (mg/100 g)                3172 non-null   object
#  72  Vitamine B5 ou Acide pantothénique (mg/100 g)          3165 non-null   object
#  73  Vitamine B6 (mg/100 g)                                 3172 non-null   object
#  74  Vitamine B9 ou Folates totaux (µg/100 g)               3166 non-null   object
#  75  Vitamine B12 (µg/100 g)                                3168 non-null   object
# dtypes: int64(4), object(72)
# memory usage: 1.8+ MB
# None
#
# FIRST ROWS
#    alim_grp_code  alim_ssgrp_code  alim_ssssgrp_code  \
# 0              0                0                  0
# 1              1              101                  0
# 2              1              101                  0
# 3              1              101                  0
# 4              1              101                  0
#
#              alim_grp_nom_fr              alim_ssgrp_nom_fr  \
# 0                        NaN                            NaN
# 1  entrées et plats composés  salades composées et crudités
# 2  entrées et plats composés  salades composées et crudités
# 3  entrées et plats composés  salades composées et crudités
# 4  entrées et plats composés  salades composées et crudités
#
#   alim_ssssgrp_nom_fr  alim_code  \
# 0                 NaN      24999
# 1                   -      25601
# 2                   -      25602
# 3                   -      25605
# 4                   -      25606
#
#                                          alim_nom_fr alim_nom_sci  \
# 0                            Dessert (aliment moyen)          NaN
# 1              Salade de thon et légumes, appertisée          NaN
# 2  Salade composée avec viande ou poisson, appert...          NaN
# 3               Champignons à la grecque, appertisés          NaN
# 4             Salade de pommes de terre, fait maison          NaN
#
#   Energie, Règlement UE N° 1169/2011 (kJ/100 g)  ... Vitamine K1 (µg/100 g)  \
# 0                                           NaN  ...                    NaN
# 1                                             -  ...                      -
# 2                                             -  ...                   9,75
# 3                                             -  ...                      -
# 4                                             -  ...                      -
#
#   Vitamine K2 (µg/100 g) Vitamine C (mg/100 g)  \
# 0                    NaN                  1,37
# 1                      -                  2,75
# 2                      -                     -
# 3                      -                  6,67
# 4                      -                    10
#
#   Vitamine B1 ou Thiamine (mg/100 g) Vitamine B2 ou Riboflavine (mg/100 g)  \
# 0                              0,084                                  0,15
# 1                             < 0,04                                 0,053
# 2                              0,032                                 0,022
# 3                              0,056                                  0,21
# 4                              0,077                                  0,06
#
#   Vitamine B3 ou PP ou Niacine (mg/100 g)  \
# 0                                    0,61
# 1                                    4,45
# 2                                    4,13
# 3                                    1,84
# 4                                    0,89
#
#   Vitamine B5 ou Acide pantothénique (mg/100 g) Vitamine B6 (mg/100 g)  \
# 0                                           0,4                  0,056
# 1                                        < 0,16                   0,29
# 2                                           0,2                   0,12
# 3                                          0,88                  0,088
# 4                                          0,53                   0,14
#
#   Vitamine B9 ou Folates totaux (µg/100 g) Vitamine B12 (µg/100 g)
# 0                                     30,8                    0,21
# 1                                       31                    1,45
# 2                                     11,1                    1,23
# 3                                     19,6                   0,018
# 4                                        7                       0
#
# [5 rows x 76 columns]
#
# LAST ROWS
#       alim_grp_code  alim_ssgrp_code  alim_ssssgrp_code      alim_grp_nom_fr  \
# 3181             11             1103                  0  aliments infantiles
# 3182             11             1104                  0  aliments infantiles
# 3183             11             1104                  0  aliments infantiles
# 3184             11             1104                  0  aliments infantiles
# 3185             11             1104                  0  aliments infantiles
#
#                     alim_ssgrp_nom_fr alim_ssssgrp_nom_fr  alim_code  \
# 3181              desserts infantiles                   -      13166
# 3182  céréales et biscuits infantiles                   -      13167
# 3183  céréales et biscuits infantiles                   -      13168
# 3184  céréales et biscuits infantiles                   -      24689
# 3185  céréales et biscuits infantiles                   -      42501
#
#                                             alim_nom_fr alim_nom_sci  \
# 3181  Dessert lacté infantile nature sucré ou aux fr...          NaN
# 3182  Céréales instantanées, poudre à reconstituer, ...          NaN
# 3183  Céréales instantanées, poudre à reconstituer, ...          NaN
# 3184                                  Biscuit pour bébé          NaN
# 3185                          Poudre cacaotée pour bébé          NaN
#
#      Energie, Règlement UE N° 1169/2011 (kJ/100 g)  ...  \
# 3181                                           420  ...
# 3182                                          1670  ...
# 3183                                          1660  ...
# 3184                                          1850  ...
# 3185                                          1680  ...
#
#      Vitamine K1 (µg/100 g) Vitamine K2 (µg/100 g) Vitamine C (mg/100 g)  \
# 3181                      -                      -                  6,72
# 3182                      -                      -                  42,7
# 3183                      -                      -                  33,4
# 3184                      -                      -                 < 0,5
# 3185                  < 0,8                      -                  29,5
#
#      Vitamine B1 ou Thiamine (mg/100 g) Vitamine B2 ou Riboflavine (mg/100 g)  \
# 3181                               0,03                                  0,11
# 3182                               0,66                                  0,04
# 3183                                0,7                                  0,04
# 3184                               0,63                                  0,62
# 3185                               0,72                                  0,06
#
#      Vitamine B3 ou PP ou Niacine (mg/100 g)  \
# 3181                                    0,12
# 3182                                    5,02
# 3183                                    4,43
# 3184                                     5,9
# 3185                                    7,89
#
#      Vitamine B5 ou Acide pantothénique (mg/100 g) Vitamine B6 (mg/100 g)  \
# 3181                                          0,26                  0,029
# 3182                                          1,33                   0,38
# 3183                                          1,58                   0,29
# 3184                                          4,69                   0,66
# 3185                                          1,12                    0,3
#
#      Vitamine B9 ou Folates totaux (µg/100 g) Vitamine B12 (µg/100 g)
# 3181                                     9,06                     0,2
# 3182                                      100                    0,44
# 3183                                     86,5                    0,29
# 3184                                     31,1                    0,28
# 3185                                      117                    0,14
#
# [5 rows x 76 columns]
#
# DUPLICATED ROWS
# Count of duplicated rows: 0
#
# MISSING VALUES BY COLUMN
#                                       column_name  missing_values_count
# 0                                   alim_grp_code                     0
# 1                                 alim_ssgrp_code                     0
# 2                               alim_ssssgrp_code                     0
# 3                                 alim_grp_nom_fr                    45
# 4                               alim_ssgrp_nom_fr                    45
# ..                                            ...                   ...
# 71        Vitamine B3 ou PP ou Niacine (mg/100 g)                    14
# 72  Vitamine B5 ou Acide pantothénique (mg/100 g)                    21
# 73                         Vitamine B6 (mg/100 g)                    14
# 74       Vitamine B9 ou Folates totaux (µg/100 g)                    20
# 75                        Vitamine B12 (µg/100 g)                    18
#
# [76 rows x 2 columns]
#
# UNIQUE VALUES BY COLUMN
#                                       column_name  unique_values_count
# 0                                   alim_grp_code                   12
# 1                                 alim_ssgrp_code                   64
# 2                               alim_ssssgrp_code                   88
# 3                                 alim_grp_nom_fr                   11
# 4                               alim_ssgrp_nom_fr                   64
# ..                                            ...                  ...
# 71        Vitamine B3 ou PP ou Niacine (mg/100 g)                  658
# 72  Vitamine B5 ou Acide pantothénique (mg/100 g)                  356
# 73                         Vitamine B6 (mg/100 g)                  250
# 74       Vitamine B9 ou Folates totaux (µg/100 g)                  781
# 75                        Vitamine B12 (µg/100 g)                  456
#
# [76 rows x 2 columns]
#
# STATISTICS
#         alim_grp_code  alim_ssgrp_code  alim_ssssgrp_code  \
# count     3186.000000      3186.000000        3186.000000
# unique            NaN              NaN                NaN
# top               NaN              NaN                NaN
# freq              NaN              NaN                NaN
# mean         4.443503       447.402699       23205.936911
# std          2.579008       258.302853       24797.496808
# min          0.000000         0.000000           0.000000
# 25%          2.000000       204.000000           0.000000
# 50%          4.000000       403.000000       20102.000000
# 75%          6.000000       602.000000       40208.000000
# max         11.000000      1104.000000      100602.000000
#
#                              alim_grp_nom_fr alim_ssgrp_nom_fr  \
# count                                   3141              3141
# unique                                    11                64
# top     viandes, œufs, poissons et assimilés           légumes
# freq                                     788               303
# mean                                     NaN               NaN
# std                                      NaN               NaN
# min                                      NaN               NaN
# 25%                                      NaN               NaN
# 50%                                      NaN               NaN
# 75%                                      NaN               NaN
# max                                      NaN               NaN
#
#        alim_ssssgrp_nom_fr     alim_code alim_nom_fr  \
# count                 3141   3186.000000        3186
# unique                  78           NaN        3185
# top                      -           NaN  Son de blé
# freq                  1259           NaN           2
# mean                   NaN  21348.921218         NaN
# std                    NaN  13085.845683         NaN
# min                    NaN   1000.000000         NaN
# 25%                    NaN  12725.250000         NaN
# 50%                    NaN  20220.000000         NaN
# 75%                    NaN  26022.750000         NaN
# max                    NaN  96781.000000         NaN
#
#                        alim_nom_sci  \
# count                           270
# unique                          127
# top     (Genus and species unknown)
# freq                             28
# mean                            NaN
# std                             NaN
# min                             NaN
# 25%                             NaN
# 50%                             NaN
# 75%                             NaN
# max                             NaN
#
#        Energie, Règlement UE N° 1169/2011 (kJ/100 g)  ...  \
# count                                           3169  ...
# unique                                           898  ...
# top                                                -  ...
# freq                                             871  ...
# mean                                             NaN  ...
# std                                              NaN  ...
# min                                              NaN  ...
# 25%                                              NaN  ...
# 50%                                              NaN  ...
# 75%                                              NaN  ...
# max                                              NaN  ...
#
#        Vitamine K1 (µg/100 g) Vitamine K2 (µg/100 g) Vitamine C (mg/100 g)  \
# count                    3123                   3071                  3165
# unique                    520                     30                   638
# top                         -                      -                     -
# freq                     1690                   3039                   913
# mean                      NaN                    NaN                   NaN
# std                       NaN                    NaN                   NaN
# min                       NaN                    NaN                   NaN
# 25%                       NaN                    NaN                   NaN
# 50%                       NaN                    NaN                   NaN
# 75%                       NaN                    NaN                   NaN
# max                       NaN                    NaN                   NaN
#
#        Vitamine B1 ou Thiamine (mg/100 g)  \
# count                                3172
# unique                                236
# top                                     -
# freq                                  786
# mean                                  NaN
# std                                   NaN
# min                                   NaN
# 25%                                   NaN
# 50%                                   NaN
# 75%                                   NaN
# max                                   NaN
#
#        Vitamine B2 ou Riboflavine (mg/100 g)  \
# count                                   3170
# unique                                   266
# top                                        -
# freq                                     800
# mean                                     NaN
# std                                      NaN
# min                                      NaN
# 25%                                      NaN
# 50%                                      NaN
# 75%                                      NaN
# max                                      NaN
#
#        Vitamine B3 ou PP ou Niacine (mg/100 g)  \
# count                                     3172
# unique                                     658
# top                                          -
# freq                                       771
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#        Vitamine B5 ou Acide pantothénique (mg/100 g) Vitamine B6 (mg/100 g)  \
# count                                           3165                   3172
# unique                                           356                    250
# top                                                -                      -
# freq                                             950                    767
# mean                                             NaN                    NaN
# std                                              NaN                    NaN
# min                                              NaN                    NaN
# 25%                                              NaN                    NaN
# 50%                                              NaN                    NaN
# 75%                                              NaN                    NaN
# max                                              NaN                    NaN
#
#        Vitamine B9 ou Folates totaux (µg/100 g) Vitamine B12 (µg/100 g)
# count                                      3166                    3168
# unique                                      781                     456
# top                                           -                       -
# freq                                        835                    1090
# mean                                        NaN                     NaN
# std                                         NaN                     NaN
# min                                         NaN                     NaN
# 25%                                         NaN                     NaN
# 50%                                         NaN                     NaN
# 75%                                         NaN                     NaN
# max                                         NaN                     NaN
#
# [11 rows x 76 columns]

# %% [markdown]
# <h3 style = "text-align: center;">Comment(s)</h3>

# %% [markdown]
# <ul>
#     <li>Column "alim_grp_code"
#         <ul>Code of the food group (e.g. "11")</ul>
#     </li>
#     <br>
#     <li>Column "alim_ssgrp_code"
#         <ul>Code of the food sub-group (e.g. "1103")</ul>
#     </li>
#     <br>
#     <li>Column "alim_ssssgrp_code"
#         <ul>Code of the food sub-sub-group (e.g. "0")</ul>
#     </li>
#     <br>
#     <li>Column "alim_grp_nom_fr"
#         <ul>French name of the food group (e.g. "aliments infantiles")</ul>
#     </li>
#     <br>
#     <li>Column "alim_ssgrp_nom_fr"
#         <ul>French name of the food sub-group (e.g. "desserts infantiles")</ul>
#     </li>
#     <br>
#     <li>Column "alim_ssssgrp_nom_fr"
#         <ul>French name of the food sub-sub-group (e.g. "-")</ul>
#     </li>
#     <br>
#     <li>Column "alim_code"
#         <ul>Code of the food (e.g. "13166")</ul>
#     </li>
#     <br>
#     <li>Column "alim_nom_fr"
#         <ul>French name of the food (e.g. "Dessert lacté infantile nature...")</ul>
#     </li>
#     <br>
#     <li>Column "alim_nom_sci"
#         <ul>Scientific name of the food (e.g. "NaN")</ul>
#     </li>
#     <br>
#     <li>Other columns
#         <ul>Nutrient content (e.g. "1,5")</ul>
#     </li>
# </ul>

# %%
# Check the unique names of the groups, sub-groups and sub-sub-groups of food
alim_grp_nom_fr_list = nutrition_cleaned_df["alim_grp_nom_fr"].unique().tolist()
print("NAME OF THE FOOD GROUPS")
print(alim_grp_nom_fr_list)
print()

alim_ssgrp_nom_fr_list = nutrition_cleaned_df["alim_ssgrp_nom_fr"].unique().tolist()
print("NAME OF THE FOOD SUB-GROUPS")
print(alim_ssgrp_nom_fr_list)
print()

alim_ssssgrp_nom_fr_list = nutrition_cleaned_df["alim_ssssgrp_nom_fr"].unique().tolist()
print("NAME OF THE FOOD SUB-SUB-GROUPS")
print(alim_ssssgrp_nom_fr_list)
print()
# Out:
# NAME OF THE FOOD GROUPS
# [nan, 'entrées et plats composés', 'fruits, légumes, légumineuses et oléagineux', 'produits céréaliers', 'viandes, œufs, poissons et assimilés', 'produits laitiers et assimilés', 'eaux et autres boissons', 'produits sucrés', 'glaces et sorbets', 'matières grasses', 'aides culinaires et ingrédients divers', 'aliments infantiles']
#
# NAME OF THE FOOD SUB-GROUPS
# [nan, 'salades composées et crudités', 'soupes', 'plats composés', 'pizzas, tartes et crêpes salées', 'sandwichs', 'feuilletées et autres entrées', 'légumes', 'pommes de terre et autres tubercules', 'légumineuses', 'fruits', 'fruits à coque et graines oléagineuses', 'pâtes, riz et céréales', 'pains et assimilés', 'biscuits apéritifs', 'viandes cuites', 'viandes crues', 'charcuteries et assimilés', 'autres produits à base de viande', 'poissons cuits', 'poissons crus', 'mollusques et crustacés cuits', 'mollusques et crustacés crus', 'produits à base de poissons et produits de la mer', 'œufs', 'substitus de produits carnés', 'laits', 'produits laitiers frais et assimilés', 'fromages et assimilés', 'crèmes et spécialités à base de crème', 'eaux', 'boissons sans alcool', 'boisson alcoolisées', 'sucres, miels et assimilés', 'chocolats et produits à base de chocolat', 'confiseries non chocolatées', 'confitures et assimilés', 'viennoiseries', 'biscuits sucrés', 'céréales de petit-déjeuner', 'barres céréalières', 'gâteaux et pâtisseries', '-', 'glaces', 'sorbets', 'desserts glacés', 'beurres', 'huiles et graisses végétales', 'margarines', 'huiles de poissons', 'autres matières grasses', 'sauces', 'condiments', 'aides culinaires', 'sels', 'épices', 'herbes', 'algues', 'denrées destinées à une alimentation particulière', 'aides culinaires et ingrédients pour végétariens', 'ingrédients divers', 'laits et boissons infantiles', 'petits pots salés et plats infantiles', 'desserts infantiles', 'céréales et biscuits infantiles']
#
# NAME OF THE FOOD SUB-SUB-GROUPS
# [nan, '-', 'plats de viande sans garniture', 'plats de viande et féculents', 'plats de viande et légumes/légumineuses', 'plats de poisson sans garniture', 'plats de poisson et féculents', 'plats de légumes/légumineuses', 'plats de céréales/pâtes', 'plats de fromage', 'plats végétariens', 'légumes crus', 'légumes cuits', 'légumes séchés ou déshydratés', 'légumes et leurs produits de la Martinique', 'légumes et leurs produits de la Réunion', 'légumineuses cuites', 'légumineuses fraîches', 'légumineuses sèches', 'fruits crus', 'compotes et assimilés', 'fruits appertisés', 'fruits séchés', 'fruits et leurs produits de la Martinique', 'fruits et leurs produits de la Réunion', 'pâtes, riz et céréales cuits', 'pâtes, riz et céréales crus', 'pains', 'biscottes et pains grillés', 'bœuf et veau', 'porc', 'poulet', 'dinde', 'agneau et mouton', 'gibier', 'autres viandes', 'abats', 'jambons cuits', 'jambons secs et crus', 'saucisson secs', 'saucisses et assimilés', 'pâtés et terrines', 'rillettes', 'quenelles', 'autres spécialités charcutières', 'substituts de charcuteries pour végétariens', 'œufs cuits', 'œufs crus', 'omelettes et autres ovoproduits', 'laits de vaches liquides (non concentrés)', 'laits autres que de vache', 'laits de vache concentrés ou en poudre', 'yaourts et spécialités laitières type yaourt', 'fromages blancs', 'desserts lactés', 'autres desserts', 'desserts végétaux', 'fromages à pâte molle', 'fromages à pâte persillée', 'fromages à pâte pressée', 'fromage fondus', 'autres fromages et spécialités', 'substituts de fromages pour végétariens', 'jus', 'nectars', 'boissons rafraîchissantes sans alcool', 'boissons rafraîchissantes lactées', 'boissons végétales', 'café, thé, cacao etc. prêts à consommer', 'boissons à reconstituer', 'vins', 'bières et cidres', 'liqueurs et alcools', 'cocktails', 'sauces condimentaires', 'sauces chaudes', 'sauces sucrées', 'herbes fraîches', 'herbes séchées']

# %% [markdown]
# ---
# <h2 style = "text-align: center;"><em>Clean and Prepare Data</em></h2>

# %% [markdown]
# <h3 style = "text-align: center;">Cleaning and Preparation</h3>

# %% [markdown]
# <h4 style = "text-align: center;">Backup</h4>

# %%
# Save the dataframe
nutrition_cleaned_df = nutrition_df.copy()

# %% [markdown]
# <h4 style = "text-align: center;">Food Group Column ("alim_grp_nom_fr")</h4>

# %%
# Check missing names of food groups
nutrition_cleaned_df.loc[nutrition_cleaned_df["alim_grp_nom_fr"].isna()]
# Out:
#       alim_grp_code  alim_ssgrp_code  alim_ssssgrp_code alim_grp_nom_fr  \
# 0                 0                0                  0             NaN
# 1097              3              305              30501             NaN
# 1098              3              305              30501             NaN
# 1099              3              305              30501             NaN
# 1100              3              305              30501             NaN
# 1101              3              305              30501             NaN
# 1102              3              305              30501             NaN
# 1103              3              305              30501             NaN
# 1104              3              305              30501             NaN
# 1105              3              305              30501             NaN
# 1106              3              305              30501             NaN
# 1107              3              305              30501             NaN
# 1108              3              305              30501             NaN
# 1109              3              305              30501             NaN
# 1110              3              305              30501             NaN
# 1111              3              305              30501             NaN
# 1112              3              305              30501             NaN
# 1113              3              305              30501             NaN
# 1114              3              305              30501             NaN
# 1115              3              305              30501             NaN
# 1116              3              305              30501             NaN
# 1117              3              305              30501             NaN
# 1118              3              305              30501             NaN
# 1119              3              305              30502             NaN
# 1120              3              305              30502             NaN
# 1121              3              305              30502             NaN
# 1122              3              305              30502             NaN
# 1123              3              305              30502             NaN
# 1124              3              305              30502             NaN
# 1125              3              305              30502             NaN
# 1126              3              305              30502             NaN
# 1127              3              305              30502             NaN
# 1128              3              305              30502             NaN
# 1129              3              305              30502             NaN
# 1130              3              305              30502             NaN
# 1131              3              305              30502             NaN
# 1132              3              305              30502             NaN
# 1133              3              305              30502             NaN
# 1134              3              305              30502             NaN
# 1135              3              305              30502             NaN
# 1136              3              305              30502             NaN
# 1137              3              305              30502             NaN
# 1138              3              305              30502             NaN
# 1139              3              305              30502             NaN
# 1140              3              305              30502             NaN
#
#      alim_ssgrp_nom_fr alim_ssssgrp_nom_fr  alim_code  \
# 0                  NaN                 NaN      24999
# 1097               NaN                 NaN       4090
# 1098               NaN                 NaN       9311
# 1099               NaN                 NaN       9410
# 1100               NaN                 NaN       9415
# 1101               NaN                 NaN       9435
# 1102               NaN                 NaN       9436
# 1103               NaN                 NaN       9437
# 1104               NaN                 NaN       9440
# 1105               NaN                 NaN       9445
# 1106               NaN                 NaN       9480
# 1107               NaN                 NaN       9510
# 1108               NaN                 NaN       9520
# 1109               NaN                 NaN       9530
# 1110               NaN                 NaN       9532
# 1111               NaN                 NaN       9533
# 1112               NaN                 NaN       9540
# 1113               NaN                 NaN       9545
# 1114               NaN                 NaN       9550
# 1115               NaN                 NaN       9555
# 1116               NaN                 NaN       9580
# 1117               NaN                 NaN      20900
# 1118               NaN                 NaN      96781
# 1119               NaN                 NaN      23402
# 1120               NaN                 NaN      23410
# 1121               NaN                 NaN      23412
# 1122               NaN                 NaN      23414
# 1123               NaN                 NaN      23415
# 1124               NaN                 NaN      23416
# 1125               NaN                 NaN      23420
# 1126               NaN                 NaN      23421
# 1127               NaN                 NaN      23422
# 1128               NaN                 NaN      23424
# 1129               NaN                 NaN      23425
# 1130               NaN                 NaN      23426
# 1131               NaN                 NaN      23430
# 1132               NaN                 NaN      23440
# 1133               NaN                 NaN      23442
# 1134               NaN                 NaN      23444
# 1135               NaN                 NaN      23445
# 1136               NaN                 NaN      23446
# 1137               NaN                 NaN      23448
# 1138               NaN                 NaN      37001
# 1139               NaN                 NaN      51550
# 1140               NaN                 NaN      96778
#
#                                             alim_nom_fr alim_nom_sci  \
# 0                               Dessert (aliment moyen)          NaN
# 1097                           Fécule de pomme de terre          NaN
# 1098                                    Flocon d'avoine          NaN
# 1099               Farine de blé tendre ou froment T110          NaN
# 1100               Farine de blé tendre ou froment T150          NaN
# 1101                Farine de blé tendre ou froment T65          NaN
# 1102   Farine de blé tendre ou froment T55 (pour pains)          NaN
# 1103  Farine de blé tendre ou froment avec levure in...          NaN
# 1104  Farine de blé tendre ou froment T45 (pour pâti...          NaN
# 1105                Farine de blé tendre ou froment T80          NaN
# 1106                 Farine d'épeautre (grand épeautre)          NaN
# 1107                   Amidon de maïs ou fécule de maïs          NaN
# 1108                                      Farine de riz          NaN
# 1109                              Farine de seigle T170          NaN
# 1110                               Farine de seigle T85          NaN
# 1111                              Farine de seigle T130          NaN
# 1112                                 Farine de sarrasin          NaN
# 1113                                     Farine de maïs          NaN
# 1114                                      Farine d'orge          NaN
# 1115                                   Farine de millet          NaN
# 1116                              Farine de pois chiche          NaN
# 1117                                     Farine de soja          NaN
# 1118                                      Amidon de riz          NaN
# 1119                            Pâte à pizza fine, crue          NaN
# 1120                                  Pâte brisée, crue          NaN
# 1121        Pâte brisée, matière grasse végétale, cuite          NaN
# 1122                      Pâte brisée, pur beurre, crue          NaN
# 1123            Pâte brisée, pur beurre, surgelée, crue          NaN
# 1124                     Pâte brisée, pur beurre, cuite          NaN
# 1125     Pâte feuilletée, matière grasse végétale, crue          NaN
# 1126                    Pâte feuilletée, surgelée, crue          NaN
# 1127                             Pâte feuilletée, cuite          NaN
# 1128                   Pâte feuilletée pur beurre, crue          NaN
# 1129          Pâte feuilletée pur beurre, surgelée crue          NaN
# 1130                  Pâte feuilletée pur beurre, cuite          NaN
# 1131  Feuille de brick, cuite à sec sans matière grasse          NaN
# 1132                                  Pâte sablée, crue          NaN
# 1133                                 Pâte sablée, cuite          NaN
# 1134                       Pâte sablée pur beurre, crue          NaN
# 1135                     Pâte phyllo ou Pâte filo, crue          NaN
# 1136             Pâte sablée pur beurre, surgelée, crue          NaN
# 1137                      Pâte sablée pur beurre, cuite          NaN
# 1138                                  Pâte à pizza crue          NaN
# 1139               Khatfa feuille de brick, préemballée          NaN
# 1140                                 Pâte à pizza cuite          NaN
#
#      Energie, Règlement UE N° 1169/2011 (kJ/100 g)  ...  \
# 0                                              NaN  ...
# 1097                                          1480  ...
# 1098                                          1550  ...
# 1099                                          1450  ...
# 1100                                          1450  ...
# 1101                                          1470  ...
# 1102                                          1480  ...
# 1103                                          1490  ...
# 1104                                          1510  ...
# 1105                                          1510  ...
# 1106                                          1490  ...
# 1107                                          1540  ...
# 1108                                          1510  ...
# 1109                                          1320  ...
# 1110                                          1460  ...
# 1111                                          1450  ...
# 1112                                          1470  ...
# 1113                                          1530  ...
# 1114                                          1430  ...
# 1115                                          1480  ...
# 1116                                          1510  ...
# 1117                                          1920  ...
# 1118                                          1460  ...
# 1119                                          1180  ...
# 1120                                          1580  ...
# 1121                                          2110  ...
# 1122                                          1600  ...
# 1123                                          1620  ...
# 1124                                          2080  ...
# 1125                                          1570  ...
# 1126                                          1670  ...
# 1127                                          2220  ...
# 1128                                          1540  ...
# 1129                                          1660  ...
# 1130                                          2120  ...
# 1131                                          1600  ...
# 1132                                          1690  ...
# 1133                                          2110  ...
# 1134                                          1610  ...
# 1135                                          1220  ...
# 1136                                          1780  ...
# 1137                                          1960  ...
# 1138                                          1020  ...
# 1139                                          1200  ...
# 1140                                          1370  ...
#
#      Vitamine K1 (µg/100 g) Vitamine K2 (µg/100 g) Vitamine C (mg/100 g)  \
# 0                       NaN                    NaN                  1,37
# 1097                      -                      -                     0
# 1098                      2                      -                     0
# 1099                  < 0,8                      -                 < 0,5
# 1100                      -                      -                 < 0,5
# 1101                      -                      -                     -
# 1102                  < 0,8                      -                 < 0,5
# 1103                      -                      -                     -
# 1104                      0                      -                     0
# 1105                      -                      -                 < 0,5
# 1106                   2,87                      -                 < 0,5
# 1107                      0                      -                     0
# 1108                   1,78                      -                 < 0,5
# 1109                    5,9                      -                     0
# 1110                    5,9                      -                     0
# 1111                    5,9                      -                 < 0,5
# 1112                      7                      -                 < 0,5
# 1113                    0,3                      -                     0
# 1114                    2,2                      -                     0
# 1115                   2,93                      -                 < 0,5
# 1116                    9,1                      -                     0
# 1117                    135                      -                     0
# 1118                      -                      -                     -
# 1119                      -                      -                     -
# 1120                      -                      -                     -
# 1121                      -                      -                     0
# 1122                      -                      -                     -
# 1123                      -                      -                     -
# 1124                   2,28                      -                 < 0,5
# 1125                      -                      -                     0
# 1126                      -                      -                     -
# 1127                      -                      -                 < 0,5
# 1128                      -                      -                     -
# 1129                      -                      -                     -
# 1130                      -                      -                     -
# 1131                      -                      -                     -
# 1132                      -                      -                     -
# 1133                   6,14                      -                 < 0,5
# 1134                      -                      -                     -
# 1135                    2,5                      -                     0
# 1136                      -                      -                     -
# 1137                   2,14                      -                 < 0,5
# 1138                      -                      -                     -
# 1139                      -                      -                     -
# 1140                    3,3                      -                 < 0,5
#
#      Vitamine B1 ou Thiamine (mg/100 g) Vitamine B2 ou Riboflavine (mg/100 g)  \
# 0                                 0,084                                  0,15
# 1097                             0,0055                                 0,005
# 1098                               0,43                                  0,14
# 1099                               0,26                                < 0,01
# 1100                               0,34                                  0,11
# 1101                               0,19                                  0,05
# 1102                               0,15                                < 0,01
# 1103                                  -                                     -
# 1104                               0,12                                 0,031
# 1105                               0,26                                  0,06
# 1106                               0,29                                < 0,01
# 1107                                  0                                 0,008
# 1108                               0,33                                < 0,01
# 1109                               0,32                                  0,25
# 1110                               0,28                                  0,07
# 1111                               0,31                                 0,098
# 1112                               0,38                                  0,15
# 1113                                0,2                                 0,084
# 1114                               0,35                                  0,11
# 1115                               0,45                                 0,043
# 1116                               0,49                                  0,11
# 1117                               0,67                                  0,74
# 1118                                  -                                     -
# 1119                                  -                                     -
# 1120                                  -                                     -
# 1121                             < 0,05                                < 0,05
# 1122                                  -                                     -
# 1123                                  -                                     -
# 1124                              0,045                                < 0,01
# 1125                               0,14                                  0,02
# 1126                                  -                                     -
# 1127                             < 0,04                                < 0,04
# 1128                                  -                                     -
# 1129                                  -                                     -
# 1130                                  -                                     -
# 1131                               0,09                                < 0,05
# 1132                                  -                                     -
# 1133                              0,041                                < 0,01
# 1134                                  -                                     -
# 1135                               0,54                                  0,34
# 1136                                  -                                     -
# 1137                              0,087                                 0,018
# 1138                                  -                                     -
# 1139                                  -                                     -
# 1140                              0,065                                  0,03
#
#      Vitamine B3 ou PP ou Niacine (mg/100 g)  \
# 0                                       0,61
# 1097                                    0,12
# 1098                                    0,96
# 1099                                   < 0,1
# 1100                                    3,48
# 1101                                    1,46
# 1102                                   < 0,1
# 1103                                       -
# 1104                                    0,89
# 1105                                     1,5
# 1106                                    0,64
# 1107                                    0,03
# 1108                                   < 0,1
# 1109                                    4,27
# 1110                                     0,8
# 1111                                    0,77
# 1112                                    4,75
# 1113                                    4,18
# 1114                                    5,98
# 1115                                   < 0,1
# 1116                                    1,76
# 1117                                    3,16
# 1118                                       -
# 1119                                       -
# 1120                                       -
# 1121                                    0,39
# 1122                                       -
# 1123                                       -
# 1124                                     0,3
# 1125                                       1
# 1126                                       -
# 1127                                    0,65
# 1128                                       -
# 1129                                       -
# 1130                                       -
# 1131                                     1,7
# 1132                                       -
# 1133                                   < 0,1
# 1134                                       -
# 1135                                    4,07
# 1136                                       -
# 1137                                   < 0,1
# 1138                                       -
# 1139                                       -
# 1140                                    0,71
#
#      Vitamine B5 ou Acide pantothénique (mg/100 g) Vitamine B6 (mg/100 g)  \
# 0                                              0,4                  0,056
# 1097                                             -                   0,01
# 1098                                          1,31                   0,12
# 1099                                          0,48                   0,11
# 1100                                          1,02                   0,26
# 1101                                           0,5                   0,08
# 1102                                          0,56                  0,054
# 1103                                             -                      -
# 1104                                          0,84                   0,06
# 1105                                           0,5                   0,13
# 1106                                          0,71                   0,21
# 1107                                             0                  0,005
# 1108                                          0,97                   0,13
# 1109                                          1,46                   0,44
# 1110                                          0,52                   0,23
# 1111                                          0,45                    0,2
# 1112                                          1,45                   0,46
# 1113                                         0,052                   0,21
# 1114                                          0,15                   0,36
# 1115                                          0,74                   0,25
# 1116                                          0,61                   0,49
# 1117                                           1,7                   0,52
# 1118                                             -                      -
# 1119                                             -                      -
# 1120                                             -                      -
# 1121                                           0,4                 < 0,05
# 1122                                             -                      -
# 1123                                             -                      -
# 1124                                          0,42                  0,019
# 1125                                             -                   0,07
# 1126                                             -                      -
# 1127                                          0,29                 < 0,04
# 1128                                             -                      -
# 1129                                             -                      -
# 1130                                             -                      -
# 1131                                          0,42                   0,08
# 1132                                             -                      -
# 1133                                          0,23                   0,03
# 1134                                             -                      -
# 1135                                           0,3                   0,03
# 1136                                             -                      -
# 1137                                          0,33                  0,055
# 1138                                             -                      -
# 1139                                             -                      -
# 1140                                          0,43                  0,048
#
#      Vitamine B9 ou Folates totaux (µg/100 g) Vitamine B12 (µg/100 g)
# 0                                        30,8                    0,21
# 1097                                       82                       0
# 1098                                     39,6                       0
# 1099                                     25,7                       0
# 1100                                     52,4                       -
# 1101                                     18,3                       -
# 1102                                     15,4                       0
# 1103                                        -                       -
# 1104                                       18                       0
# 1105                                     53,8                       -
# 1106                                     59,3                       -
# 1107                                        1                       0
# 1108                                     25,1                       0
# 1109                                       33                       0
# 1110                                       23                       0
# 1111                                     50,3                       0
# 1112                                     66,8                       0
# 1113                                       34                       0
# 1114                                        8                       0
# 1115                                     54,5                       -
# 1116                                      437                       0
# 1117                                      573                       0
# 1118                                        -                       -
# 1119                                        -                       -
# 1120                                        -                       -
# 1121                                        8                    0,03
# 1122                                        -                       -
# 1123                                        -                       -
# 1124                                     17,9                       -
# 1125                                        7                       -
# 1126                                        -                       -
# 1127                                      0,8                       -
# 1128                                        -                       -
# 1129                                        -                       -
# 1130                                        -                       -
# 1131                                     12,4                       -
# 1132                                        -                       -
# 1133                                     81,6                  < 0,01
# 1134                                        -                       -
# 1135                                       18                       0
# 1136                                        -                       -
# 1137                                       99                   0,096
# 1138                                        -                       -
# 1139                                        -                       -
# 1140                                     25,8                   0,019
#
# [45 rows x 76 columns]

# %%
# Replace missing values by relevant names of food groups
nutrition_cleaned_df.loc[
    (nutrition_cleaned_df["alim_grp_nom_fr"].isna()) & (nutrition_cleaned_df["alim_grp_code"] == 3),
    "alim_grp_nom_fr"
] = "farines, amidons et bases de pâtes"

nutrition_cleaned_df.loc[
    (nutrition_cleaned_df["alim_grp_nom_fr"] == "farines, amidons et bases de pâtes") & (nutrition_cleaned_df["alim_nom_fr"].str.startswith("Farine")),
    ["alim_ssgrp_nom_fr", "alim_ssssgrp_nom_fr"]
] = "farines"

nutrition_cleaned_df.loc[
    (nutrition_cleaned_df["alim_grp_nom_fr"] == "farines, amidons et bases de pâtes") & (nutrition_cleaned_df["alim_nom_fr"].str.startswith("Amidon")),
    ["alim_ssgrp_nom_fr", "alim_ssssgrp_nom_fr"]
] = "amidons"

nutrition_cleaned_df.loc[
    [1097, 1098],
    ["alim_ssgrp_nom_fr", "alim_ssssgrp_nom_fr"]
] = "amidons"

nutrition_cleaned_df.loc[
    (nutrition_cleaned_df["alim_grp_nom_fr"] == "farines, amidons et bases de pâtes") & (nutrition_cleaned_df["alim_nom_fr"].str.startswith("Pâte")),
    ["alim_ssgrp_nom_fr", "alim_ssssgrp_nom_fr"]
] = "bases de pâtes"

nutrition_cleaned_df.loc[
    (nutrition_cleaned_df["alim_grp_nom_fr"] == "farines, amidons et bases de pâtes") & (nutrition_cleaned_df["alim_nom_fr"].str.contains("brick")),
    ["alim_ssgrp_nom_fr", "alim_ssssgrp_nom_fr"]
] = "bases de pâtes"

# Drop irrelevant row
irrelevant_row = nutrition_cleaned_df[(nutrition_cleaned_df["alim_grp_nom_fr"].isna()) & (nutrition_cleaned_df["alim_grp_code"] == 0)].index
nutrition_cleaned_df.drop(irrelevant_row, inplace = True)

# Check the replacements of the names of food groups
nutrition_cleaned_df.loc[nutrition_cleaned_df["alim_grp_nom_fr"] == "farines, amidons et bases de pâtes"]
# Out:
#       alim_grp_code  alim_ssgrp_code  alim_ssssgrp_code  \
# 1097              3              305              30501
# 1098              3              305              30501
# 1099              3              305              30501
# 1100              3              305              30501
# 1101              3              305              30501
# 1102              3              305              30501
# 1103              3              305              30501
# 1104              3              305              30501
# 1105              3              305              30501
# 1106              3              305              30501
# 1107              3              305              30501
# 1108              3              305              30501
# 1109              3              305              30501
# 1110              3              305              30501
# 1111              3              305              30501
# 1112              3              305              30501
# 1113              3              305              30501
# 1114              3              305              30501
# 1115              3              305              30501
# 1116              3              305              30501
# 1117              3              305              30501
# 1118              3              305              30501
# 1119              3              305              30502
# 1120              3              305              30502
# 1121              3              305              30502
# 1122              3              305              30502
# 1123              3              305              30502
# 1124              3              305              30502
# 1125              3              305              30502
# 1126              3              305              30502
# 1127              3              305              30502
# 1128              3              305              30502
# 1129              3              305              30502
# 1130              3              305              30502
# 1131              3              305              30502
# 1132              3              305              30502
# 1133              3              305              30502
# 1134              3              305              30502
# 1135              3              305              30502
# 1136              3              305              30502
# 1137              3              305              30502
# 1138              3              305              30502
# 1139              3              305              30502
# 1140              3              305              30502
#
#                          alim_grp_nom_fr alim_ssgrp_nom_fr  \
# 1097  farines, amidons et bases de pâtes           amidons
# 1098  farines, amidons et bases de pâtes           amidons
# 1099  farines, amidons et bases de pâtes           farines
# 1100  farines, amidons et bases de pâtes           farines
# 1101  farines, amidons et bases de pâtes           farines
# 1102  farines, amidons et bases de pâtes           farines
# 1103  farines, amidons et bases de pâtes           farines
# 1104  farines, amidons et bases de pâtes           farines
# 1105  farines, amidons et bases de pâtes           farines
# 1106  farines, amidons et bases de pâtes           farines
# 1107  farines, amidons et bases de pâtes           amidons
# 1108  farines, amidons et bases de pâtes           farines
# 1109  farines, amidons et bases de pâtes           farines
# 1110  farines, amidons et bases de pâtes           farines
# 1111  farines, amidons et bases de pâtes           farines
# 1112  farines, amidons et bases de pâtes           farines
# 1113  farines, amidons et bases de pâtes           farines
# 1114  farines, amidons et bases de pâtes           farines
# 1115  farines, amidons et bases de pâtes           farines
# 1116  farines, amidons et bases de pâtes           farines
# 1117  farines, amidons et bases de pâtes           farines
# 1118  farines, amidons et bases de pâtes           amidons
# 1119  farines, amidons et bases de pâtes    bases de pâtes
# 1120  farines, amidons et bases de pâtes    bases de pâtes
# 1121  farines, amidons et bases de pâtes    bases de pâtes
# 1122  farines, amidons et bases de pâtes    bases de pâtes
# 1123  farines, amidons et bases de pâtes    bases de pâtes
# 1124  farines, amidons et bases de pâtes    bases de pâtes
# 1125  farines, amidons et bases de pâtes    bases de pâtes
# 1126  farines, amidons et bases de pâtes    bases de pâtes
# 1127  farines, amidons et bases de pâtes    bases de pâtes
# 1128  farines, amidons et bases de pâtes    bases de pâtes
# 1129  farines, amidons et bases de pâtes    bases de pâtes
# 1130  farines, amidons et bases de pâtes    bases de pâtes
# 1131  farines, amidons et bases de pâtes    bases de pâtes
# 1132  farines, amidons et bases de pâtes    bases de pâtes
# 1133  farines, amidons et bases de pâtes    bases de pâtes
# 1134  farines, amidons et bases de pâtes    bases de pâtes
# 1135  farines, amidons et bases de pâtes    bases de pâtes
# 1136  farines, amidons et bases de pâtes    bases de pâtes
# 1137  farines, amidons et bases de pâtes    bases de pâtes
# 1138  farines, amidons et bases de pâtes    bases de pâtes
# 1139  farines, amidons et bases de pâtes    bases de pâtes
# 1140  farines, amidons et bases de pâtes    bases de pâtes
#
#      alim_ssssgrp_nom_fr  alim_code  \
# 1097             amidons       4090
# 1098             amidons       9311
# 1099             farines       9410
# 1100             farines       9415
# 1101             farines       9435
# 1102             farines       9436
# 1103             farines       9437
# 1104             farines       9440
# 1105             farines       9445
# 1106             farines       9480
# 1107             amidons       9510
# 1108             farines       9520
# 1109             farines       9530
# 1110             farines       9532
# 1111             farines       9533
# 1112             farines       9540
# 1113             farines       9545
# 1114             farines       9550
# 1115             farines       9555
# 1116             farines       9580
# 1117             farines      20900
# 1118             amidons      96781
# 1119      bases de pâtes      23402
# 1120      bases de pâtes      23410
# 1121      bases de pâtes      23412
# 1122      bases de pâtes      23414
# 1123      bases de pâtes      23415
# 1124      bases de pâtes      23416
# 1125      bases de pâtes      23420
# 1126      bases de pâtes      23421
# 1127      bases de pâtes      23422
# 1128      bases de pâtes      23424
# 1129      bases de pâtes      23425
# 1130      bases de pâtes      23426
# 1131      bases de pâtes      23430
# 1132      bases de pâtes      23440
# 1133      bases de pâtes      23442
# 1134      bases de pâtes      23444
# 1135      bases de pâtes      23445
# 1136      bases de pâtes      23446
# 1137      bases de pâtes      23448
# 1138      bases de pâtes      37001
# 1139      bases de pâtes      51550
# 1140      bases de pâtes      96778
#
#                                             alim_nom_fr alim_nom_sci  \
# 1097                           Fécule de pomme de terre          NaN
# 1098                                    Flocon d'avoine          NaN
# 1099               Farine de blé tendre ou froment T110          NaN
# 1100               Farine de blé tendre ou froment T150          NaN
# 1101                Farine de blé tendre ou froment T65          NaN
# 1102   Farine de blé tendre ou froment T55 (pour pains)          NaN
# 1103  Farine de blé tendre ou froment avec levure in...          NaN
# 1104  Farine de blé tendre ou froment T45 (pour pâti...          NaN
# 1105                Farine de blé tendre ou froment T80          NaN
# 1106                 Farine d'épeautre (grand épeautre)          NaN
# 1107                   Amidon de maïs ou fécule de maïs          NaN
# 1108                                      Farine de riz          NaN
# 1109                              Farine de seigle T170          NaN
# 1110                               Farine de seigle T85          NaN
# 1111                              Farine de seigle T130          NaN
# 1112                                 Farine de sarrasin          NaN
# 1113                                     Farine de maïs          NaN
# 1114                                      Farine d'orge          NaN
# 1115                                   Farine de millet          NaN
# 1116                              Farine de pois chiche          NaN
# 1117                                     Farine de soja          NaN
# 1118                                      Amidon de riz          NaN
# 1119                            Pâte à pizza fine, crue          NaN
# 1120                                  Pâte brisée, crue          NaN
# 1121        Pâte brisée, matière grasse végétale, cuite          NaN
# 1122                      Pâte brisée, pur beurre, crue          NaN
# 1123            Pâte brisée, pur beurre, surgelée, crue          NaN
# 1124                     Pâte brisée, pur beurre, cuite          NaN
# 1125     Pâte feuilletée, matière grasse végétale, crue          NaN
# 1126                    Pâte feuilletée, surgelée, crue          NaN
# 1127                             Pâte feuilletée, cuite          NaN
# 1128                   Pâte feuilletée pur beurre, crue          NaN
# 1129          Pâte feuilletée pur beurre, surgelée crue          NaN
# 1130                  Pâte feuilletée pur beurre, cuite          NaN
# 1131  Feuille de brick, cuite à sec sans matière grasse          NaN
# 1132                                  Pâte sablée, crue          NaN
# 1133                                 Pâte sablée, cuite          NaN
# 1134                       Pâte sablée pur beurre, crue          NaN
# 1135                     Pâte phyllo ou Pâte filo, crue          NaN
# 1136             Pâte sablée pur beurre, surgelée, crue          NaN
# 1137                      Pâte sablée pur beurre, cuite          NaN
# 1138                                  Pâte à pizza crue          NaN
# 1139               Khatfa feuille de brick, préemballée          NaN
# 1140                                 Pâte à pizza cuite          NaN
#
#      Energie, Règlement UE N° 1169/2011 (kJ/100 g)  ...  \
# 1097                                          1480  ...
# 1098                                          1550  ...
# 1099                                          1450  ...
# 1100                                          1450  ...
# 1101                                          1470  ...
# 1102                                          1480  ...
# 1103                                          1490  ...
# 1104                                          1510  ...
# 1105                                          1510  ...
# 1106                                          1490  ...
# 1107                                          1540  ...
# 1108                                          1510  ...
# 1109                                          1320  ...
# 1110                                          1460  ...
# 1111                                          1450  ...
# 1112                                          1470  ...
# 1113                                          1530  ...
# 1114                                          1430  ...
# 1115                                          1480  ...
# 1116                                          1510  ...
# 1117                                          1920  ...
# 1118                                          1460  ...
# 1119                                          1180  ...
# 1120                                          1580  ...
# 1121                                          2110  ...
# 1122                                          1600  ...
# 1123                                          1620  ...
# 1124                                          2080  ...
# 1125                                          1570  ...
# 1126                                          1670  ...
# 1127                                          2220  ...
# 1128                                          1540  ...
# 1129                                          1660  ...
# 1130                                          2120  ...
# 1131                                          1600  ...
# 1132                                          1690  ...
# 1133                                          2110  ...
# 1134                                          1610  ...
# 1135                                          1220  ...
# 1136                                          1780  ...
# 1137                                          1960  ...
# 1138                                          1020  ...
# 1139                                          1200  ...
# 1140                                          1370  ...
#
#      Vitamine K1 (µg/100 g) Vitamine K2 (µg/100 g) Vitamine C (mg/100 g)  \
# 1097                      -                      -                     0
# 1098                      2                      -                     0
# 1099                  < 0,8                      -                 < 0,5
# 1100                      -                      -                 < 0,5
# 1101                      -                      -                     -
# 1102                  < 0,8                      -                 < 0,5
# 1103                      -                      -                     -
# 1104                      0                      -                     0
# 1105                      -                      -                 < 0,5
# 1106                   2,87                      -                 < 0,5
# 1107                      0                      -                     0
# 1108                   1,78                      -                 < 0,5
# 1109                    5,9                      -                     0
# 1110                    5,9                      -                     0
# 1111                    5,9                      -                 < 0,5
# 1112                      7                      -                 < 0,5
# 1113                    0,3                      -                     0
# 1114                    2,2                      -                     0
# 1115                   2,93                      -                 < 0,5
# 1116                    9,1                      -                     0
# 1117                    135                      -                     0
# 1118                      -                      -                     -
# 1119                      -                      -                     -
# 1120                      -                      -                     -
# 1121                      -                      -                     0
# 1122                      -                      -                     -
# 1123                      -                      -                     -
# 1124                   2,28                      -                 < 0,5
# 1125                      -                      -                     0
# 1126                      -                      -                     -
# 1127                      -                      -                 < 0,5
# 1128                      -                      -                     -
# 1129                      -                      -                     -
# 1130                      -                      -                     -
# 1131                      -                      -                     -
# 1132                      -                      -                     -
# 1133                   6,14                      -                 < 0,5
# 1134                      -                      -                     -
# 1135                    2,5                      -                     0
# 1136                      -                      -                     -
# 1137                   2,14                      -                 < 0,5
# 1138                      -                      -                     -
# 1139                      -                      -                     -
# 1140                    3,3                      -                 < 0,5
#
#      Vitamine B1 ou Thiamine (mg/100 g) Vitamine B2 ou Riboflavine (mg/100 g)  \
# 1097                             0,0055                                 0,005
# 1098                               0,43                                  0,14
# 1099                               0,26                                < 0,01
# 1100                               0,34                                  0,11
# 1101                               0,19                                  0,05
# 1102                               0,15                                < 0,01
# 1103                                  -                                     -
# 1104                               0,12                                 0,031
# 1105                               0,26                                  0,06
# 1106                               0,29                                < 0,01
# 1107                                  0                                 0,008
# 1108                               0,33                                < 0,01
# 1109                               0,32                                  0,25
# 1110                               0,28                                  0,07
# 1111                               0,31                                 0,098
# 1112                               0,38                                  0,15
# 1113                                0,2                                 0,084
# 1114                               0,35                                  0,11
# 1115                               0,45                                 0,043
# 1116                               0,49                                  0,11
# 1117                               0,67                                  0,74
# 1118                                  -                                     -
# 1119                                  -                                     -
# 1120                                  -                                     -
# 1121                             < 0,05                                < 0,05
# 1122                                  -                                     -
# 1123                                  -                                     -
# 1124                              0,045                                < 0,01
# 1125                               0,14                                  0,02
# 1126                                  -                                     -
# 1127                             < 0,04                                < 0,04
# 1128                                  -                                     -
# 1129                                  -                                     -
# 1130                                  -                                     -
# 1131                               0,09                                < 0,05
# 1132                                  -                                     -
# 1133                              0,041                                < 0,01
# 1134                                  -                                     -
# 1135                               0,54                                  0,34
# 1136                                  -                                     -
# 1137                              0,087                                 0,018
# 1138                                  -                                     -
# 1139                                  -                                     -
# 1140                              0,065                                  0,03
#
#      Vitamine B3 ou PP ou Niacine (mg/100 g)  \
# 1097                                    0,12
# 1098                                    0,96
# 1099                                   < 0,1
# 1100                                    3,48
# 1101                                    1,46
# 1102                                   < 0,1
# 1103                                       -
# 1104                                    0,89
# 1105                                     1,5
# 1106                                    0,64
# 1107                                    0,03
# 1108                                   < 0,1
# 1109                                    4,27
# 1110                                     0,8
# 1111                                    0,77
# 1112                                    4,75
# 1113                                    4,18
# 1114                                    5,98
# 1115                                   < 0,1
# 1116                                    1,76
# 1117                                    3,16
# 1118                                       -
# 1119                                       -
# 1120                                       -
# 1121                                    0,39
# 1122                                       -
# 1123                                       -
# 1124                                     0,3
# 1125                                       1
# 1126                                       -
# 1127                                    0,65
# 1128                                       -
# 1129                                       -
# 1130                                       -
# 1131                                     1,7
# 1132                                       -
# 1133                                   < 0,1
# 1134                                       -
# 1135                                    4,07
# 1136                                       -
# 1137                                   < 0,1
# 1138                                       -
# 1139                                       -
# 1140                                    0,71
#
#      Vitamine B5 ou Acide pantothénique (mg/100 g) Vitamine B6 (mg/100 g)  \
# 1097                                             -                   0,01
# 1098                                          1,31                   0,12
# 1099                                          0,48                   0,11
# 1100                                          1,02                   0,26
# 1101                                           0,5                   0,08
# 1102                                          0,56                  0,054
# 1103                                             -                      -
# 1104                                          0,84                   0,06
# 1105                                           0,5                   0,13
# 1106                                          0,71                   0,21
# 1107                                             0                  0,005
# 1108                                          0,97                   0,13
# 1109                                          1,46                   0,44
# 1110                                          0,52                   0,23
# 1111                                          0,45                    0,2
# 1112                                          1,45                   0,46
# 1113                                         0,052                   0,21
# 1114                                          0,15                   0,36
# 1115                                          0,74                   0,25
# 1116                                          0,61                   0,49
# 1117                                           1,7                   0,52
# 1118                                             -                      -
# 1119                                             -                      -
# 1120                                             -                      -
# 1121                                           0,4                 < 0,05
# 1122                                             -                      -
# 1123                                             -                      -
# 1124                                          0,42                  0,019
# 1125                                             -                   0,07
# 1126                                             -                      -
# 1127                                          0,29                 < 0,04
# 1128                                             -                      -
# 1129                                             -                      -
# 1130                                             -                      -
# 1131                                          0,42                   0,08
# 1132                                             -                      -
# 1133                                          0,23                   0,03
# 1134                                             -                      -
# 1135                                           0,3                   0,03
# 1136                                             -                      -
# 1137                                          0,33                  0,055
# 1138                                             -                      -
# 1139                                             -                      -
# 1140                                          0,43                  0,048
#
#      Vitamine B9 ou Folates totaux (µg/100 g) Vitamine B12 (µg/100 g)
# 1097                                       82                       0
# 1098                                     39,6                       0
# 1099                                     25,7                       0
# 1100                                     52,4                       -
# 1101                                     18,3                       -
# 1102                                     15,4                       0
# 1103                                        -                       -
# 1104                                       18                       0
# 1105                                     53,8                       -
# 1106                                     59,3                       -
# 1107                                        1                       0
# 1108                                     25,1                       0
# 1109                                       33                       0
# 1110                                       23                       0
# 1111                                     50,3                       0
# 1112                                     66,8                       0
# 1113                                       34                       0
# 1114                                        8                       0
# 1115                                     54,5                       -
# 1116                                      437                       0
# 1117                                      573                       0
# 1118                                        -                       -
# 1119                                        -                       -
# 1120                                        -                       -
# 1121                                        8                    0,03
# 1122                                        -                       -
# 1123                                        -                       -
# 1124                                     17,9                       -
# 1125                                        7                       -
# 1126                                        -                       -
# 1127                                      0,8                       -
# 1128                                        -                       -
# 1129                                        -                       -
# 1130                                        -                       -
# 1131                                     12,4                       -
# 1132                                        -                       -
# 1133                                     81,6                  < 0,01
# 1134                                        -                       -
# 1135                                       18                       0
# 1136                                        -                       -
# 1137                                       99                   0,096
# 1138                                        -                       -
# 1139                                        -                       -
# 1140                                     25,8                   0,019
#
# [44 rows x 76 columns]

# %% [markdown]
# <h4 style = "text-align: center;">Food Sub-Group Column ("alim_ssgrp_nom_fr")</h4>

# %%
# Check "-" name of food sub-groups
nutrition_cleaned_df.loc[nutrition_cleaned_df["alim_ssgrp_nom_fr"] == "-"]
# Out:
#       alim_grp_code  alim_ssgrp_code  alim_ssssgrp_code    alim_grp_nom_fr  \
# 2831              8                0                  0  glaces et sorbets
#
#      alim_ssgrp_nom_fr alim_ssssgrp_nom_fr  alim_code  \
# 2831                 -                   -      39500
#
#                                             alim_nom_fr alim_nom_sci  \
# 2831  Glace à l'eau ou sorbet ou crème glacée, tout ...          NaN
#
#      Energie, Règlement UE N° 1169/2011 (kJ/100 g)  ...  \
# 2831                                           NaN  ...
#
#      Vitamine K1 (µg/100 g) Vitamine K2 (µg/100 g) Vitamine C (mg/100 g)  \
# 2831                    NaN                    NaN                  1,12
#
#      Vitamine B1 ou Thiamine (mg/100 g) Vitamine B2 ou Riboflavine (mg/100 g)  \
# 2831                              0,036                                  0,16
#
#      Vitamine B3 ou PP ou Niacine (mg/100 g)  \
# 2831                                    0,18
#
#      Vitamine B5 ou Acide pantothénique (mg/100 g) Vitamine B6 (mg/100 g)  \
# 2831                                          0,28                  0,046
#
#      Vitamine B9 ou Folates totaux (µg/100 g) Vitamine B12 (µg/100 g)
# 2831                                     4,03                    0,17
#
# [1 rows x 76 columns]

# %%
# Replace "-" values by a relevant name of food sub-group
nutrition_cleaned_df.loc[
    nutrition_cleaned_df["alim_ssgrp_nom_fr"] == "-",
    ["alim_ssgrp_nom_fr", "alim_ssssgrp_nom_fr"]
] = "glaces et sorbets"

# Check the replacement of the "-" name of the food group
nutrition_cleaned_df.loc[nutrition_cleaned_df["alim_ssgrp_nom_fr"] == "glaces et sorbets"]
# Out:
#       alim_grp_code  alim_ssgrp_code  alim_ssssgrp_code    alim_grp_nom_fr  \
# 2831              8                0                  0  glaces et sorbets
#
#       alim_ssgrp_nom_fr alim_ssssgrp_nom_fr  alim_code  \
# 2831  glaces et sorbets   glaces et sorbets      39500
#
#                                             alim_nom_fr alim_nom_sci  \
# 2831  Glace à l'eau ou sorbet ou crème glacée, tout ...          NaN
#
#      Energie, Règlement UE N° 1169/2011 (kJ/100 g)  ...  \
# 2831                                           NaN  ...
#
#      Vitamine K1 (µg/100 g) Vitamine K2 (µg/100 g) Vitamine C (mg/100 g)  \
# 2831                    NaN                    NaN                  1,12
#
#      Vitamine B1 ou Thiamine (mg/100 g) Vitamine B2 ou Riboflavine (mg/100 g)  \
# 2831                              0,036                                  0,16
#
#      Vitamine B3 ou PP ou Niacine (mg/100 g)  \
# 2831                                    0,18
#
#      Vitamine B5 ou Acide pantothénique (mg/100 g) Vitamine B6 (mg/100 g)  \
# 2831                                          0,28                  0,046
#
#      Vitamine B9 ou Folates totaux (µg/100 g) Vitamine B12 (µg/100 g)
# 2831                                     4,03                    0,17
#
# [1 rows x 76 columns]

# %% [markdown]
# <h4 style = "text-align: center;">Food Sub-Sub-Group Column ("alim_ssssgrp_nom_fr")</h4>

# %%
# Check "-" name of food sub-sub-groups
nutrition_cleaned_df.loc[nutrition_cleaned_df["alim_ssssgrp_nom_fr"] == "-"]
# Out:
#       alim_grp_code  alim_ssgrp_code  alim_ssssgrp_code  \
# 1                 1              101                  0
# 2                 1              101                  0
# 3                 1              101                  0
# 4                 1              101                  0
# 5                 1              101                  0
# ...             ...              ...                ...
# 3181             11             1103                  0
# 3182             11             1104                  0
# 3183             11             1104                  0
# 3184             11             1104                  0
# 3185             11             1104                  0
#
#                 alim_grp_nom_fr                alim_ssgrp_nom_fr  \
# 1     entrées et plats composés    salades composées et crudités
# 2     entrées et plats composés    salades composées et crudités
# 3     entrées et plats composés    salades composées et crudités
# 4     entrées et plats composés    salades composées et crudités
# 5     entrées et plats composés    salades composées et crudités
# ...                         ...                              ...
# 3181        aliments infantiles              desserts infantiles
# 3182        aliments infantiles  céréales et biscuits infantiles
# 3183        aliments infantiles  céréales et biscuits infantiles
# 3184        aliments infantiles  céréales et biscuits infantiles
# 3185        aliments infantiles  céréales et biscuits infantiles
#
#      alim_ssssgrp_nom_fr  alim_code  \
# 1                      -      25601
# 2                      -      25602
# 3                      -      25605
# 4                      -      25606
# 5                      -      25608
# ...                  ...        ...
# 3181                   -      13166
# 3182                   -      13167
# 3183                   -      13168
# 3184                   -      24689
# 3185                   -      42501
#
#                                             alim_nom_fr alim_nom_sci  \
# 1                 Salade de thon et légumes, appertisée          NaN
# 2     Salade composée avec viande ou poisson, appert...          NaN
# 3                  Champignons à la grecque, appertisés          NaN
# 4                Salade de pommes de terre, fait maison          NaN
# 5             Taboulé ou Salade de couscous, préemballé          NaN
# ...                                                 ...          ...
# 3181  Dessert lacté infantile nature sucré ou aux fr...          NaN
# 3182  Céréales instantanées, poudre à reconstituer, ...          NaN
# 3183  Céréales instantanées, poudre à reconstituer, ...          NaN
# 3184                                  Biscuit pour bébé          NaN
# 3185                          Poudre cacaotée pour bébé          NaN
#
#      Energie, Règlement UE N° 1169/2011 (kJ/100 g)  ...  \
# 1                                                -  ...
# 2                                                -  ...
# 3                                                -  ...
# 4                                                -  ...
# 5                                              753  ...
# ...                                            ...  ...
# 3181                                           420  ...
# 3182                                          1670  ...
# 3183                                          1660  ...
# 3184                                          1850  ...
# 3185                                          1680  ...
#
#      Vitamine K1 (µg/100 g) Vitamine K2 (µg/100 g) Vitamine C (mg/100 g)  \
# 1                         -                      -                  2,75
# 2                      9,75                      -                     -
# 3                         -                      -                  6,67
# 4                         -                      -                    10
# 5                      10,6                      -                  6,27
# ...                     ...                    ...                   ...
# 3181                      -                      -                  6,72
# 3182                      -                      -                  42,7
# 3183                      -                      -                  33,4
# 3184                      -                      -                 < 0,5
# 3185                  < 0,8                      -                  29,5
#
#      Vitamine B1 ou Thiamine (mg/100 g) Vitamine B2 ou Riboflavine (mg/100 g)  \
# 1                                < 0,04                                 0,053
# 2                                 0,032                                 0,022
# 3                                 0,056                                  0,21
# 4                                 0,077                                  0,06
# 5                                 0,087                                 0,024
# ...                                 ...                                   ...
# 3181                               0,03                                  0,11
# 3182                               0,66                                  0,04
# 3183                                0,7                                  0,04
# 3184                               0,63                                  0,62
# 3185                               0,72                                  0,06
#
#      Vitamine B3 ou PP ou Niacine (mg/100 g)  \
# 1                                       4,45
# 2                                       4,13
# 3                                       1,84
# 4                                       0,89
# 5                                        0,5
# ...                                      ...
# 3181                                    0,12
# 3182                                    5,02
# 3183                                    4,43
# 3184                                     5,9
# 3185                                    7,89
#
#      Vitamine B5 ou Acide pantothénique (mg/100 g) Vitamine B6 (mg/100 g)  \
# 1                                           < 0,16                   0,29
# 2                                              0,2                   0,12
# 3                                             0,88                  0,088
# 4                                             0,53                   0,14
# 5                                             0,26                  0,052
# ...                                            ...                    ...
# 3181                                          0,26                  0,029
# 3182                                          1,33                   0,38
# 3183                                          1,58                   0,29
# 3184                                          4,69                   0,66
# 3185                                          1,12                    0,3
#
#      Vitamine B9 ou Folates totaux (µg/100 g) Vitamine B12 (µg/100 g)
# 1                                          31                    1,45
# 2                                        11,1                    1,23
# 3                                        19,6                   0,018
# 4                                           7                       0
# 5                                        14,5                       0
# ...                                       ...                     ...
# 3181                                     9,06                     0,2
# 3182                                      100                    0,44
# 3183                                     86,5                    0,29
# 3184                                     31,1                    0,28
# 3185                                      117                    0,14
#
# [1258 rows x 76 columns]

# %%
# Replace "-" values by a relevant name of food sub-group
nutrition_cleaned_df.loc[
    nutrition_cleaned_df["alim_ssssgrp_nom_fr"] == "-",
    "alim_ssssgrp_nom_fr"
] = "sous-sous-catégories non définie"

# Check the replacement of the name of the food groups
nutrition_cleaned_df.loc[nutrition_cleaned_df["alim_ssssgrp_nom_fr"] == "sous-sous-catégories non définie"]
# Out:
#       alim_grp_code  alim_ssgrp_code  alim_ssssgrp_code  \
# 1                 1              101                  0
# 2                 1              101                  0
# 3                 1              101                  0
# 4                 1              101                  0
# 5                 1              101                  0
# ...             ...              ...                ...
# 3181             11             1103                  0
# 3182             11             1104                  0
# 3183             11             1104                  0
# 3184             11             1104                  0
# 3185             11             1104                  0
#
#                 alim_grp_nom_fr                alim_ssgrp_nom_fr  \
# 1     entrées et plats composés    salades composées et crudités
# 2     entrées et plats composés    salades composées et crudités
# 3     entrées et plats composés    salades composées et crudités
# 4     entrées et plats composés    salades composées et crudités
# 5     entrées et plats composés    salades composées et crudités
# ...                         ...                              ...
# 3181        aliments infantiles              desserts infantiles
# 3182        aliments infantiles  céréales et biscuits infantiles
# 3183        aliments infantiles  céréales et biscuits infantiles
# 3184        aliments infantiles  céréales et biscuits infantiles
# 3185        aliments infantiles  céréales et biscuits infantiles
#
#                    alim_ssssgrp_nom_fr  alim_code  \
# 1     sous-sous-catégories non définie      25601
# 2     sous-sous-catégories non définie      25602
# 3     sous-sous-catégories non définie      25605
# 4     sous-sous-catégories non définie      25606
# 5     sous-sous-catégories non définie      25608
# ...                                ...        ...
# 3181  sous-sous-catégories non définie      13166
# 3182  sous-sous-catégories non définie      13167
# 3183  sous-sous-catégories non définie      13168
# 3184  sous-sous-catégories non définie      24689
# 3185  sous-sous-catégories non définie      42501
#
#                                             alim_nom_fr alim_nom_sci  \
# 1                 Salade de thon et légumes, appertisée          NaN
# 2     Salade composée avec viande ou poisson, appert...          NaN
# 3                  Champignons à la grecque, appertisés          NaN
# 4                Salade de pommes de terre, fait maison          NaN
# 5             Taboulé ou Salade de couscous, préemballé          NaN
# ...                                                 ...          ...
# 3181  Dessert lacté infantile nature sucré ou aux fr...          NaN
# 3182  Céréales instantanées, poudre à reconstituer, ...          NaN
# 3183  Céréales instantanées, poudre à reconstituer, ...          NaN
# 3184                                  Biscuit pour bébé          NaN
# 3185                          Poudre cacaotée pour bébé          NaN
#
#      Energie, Règlement UE N° 1169/2011 (kJ/100 g)  ...  \
# 1                                                -  ...
# 2                                                -  ...
# 3                                                -  ...
# 4                                                -  ...
# 5                                              753  ...
# ...                                            ...  ...
# 3181                                           420  ...
# 3182                                          1670  ...
# 3183                                          1660  ...
# 3184                                          1850  ...
# 3185                                          1680  ...
#
#      Vitamine K1 (µg/100 g) Vitamine K2 (µg/100 g) Vitamine C (mg/100 g)  \
# 1                         -                      -                  2,75
# 2                      9,75                      -                     -
# 3                         -                      -                  6,67
# 4                         -                      -                    10
# 5                      10,6                      -                  6,27
# ...                     ...                    ...                   ...
# 3181                      -                      -                  6,72
# 3182                      -                      -                  42,7
# 3183                      -                      -                  33,4
# 3184                      -                      -                 < 0,5
# 3185                  < 0,8                      -                  29,5
#
#      Vitamine B1 ou Thiamine (mg/100 g) Vitamine B2 ou Riboflavine (mg/100 g)  \
# 1                                < 0,04                                 0,053
# 2                                 0,032                                 0,022
# 3                                 0,056                                  0,21
# 4                                 0,077                                  0,06
# 5                                 0,087                                 0,024
# ...                                 ...                                   ...
# 3181                               0,03                                  0,11
# 3182                               0,66                                  0,04
# 3183                                0,7                                  0,04
# 3184                               0,63                                  0,62
# 3185                               0,72                                  0,06
#
#      Vitamine B3 ou PP ou Niacine (mg/100 g)  \
# 1                                       4,45
# 2                                       4,13
# 3                                       1,84
# 4                                       0,89
# 5                                        0,5
# ...                                      ...
# 3181                                    0,12
# 3182                                    5,02
# 3183                                    4,43
# 3184                                     5,9
# 3185                                    7,89
#
#      Vitamine B5 ou Acide pantothénique (mg/100 g) Vitamine B6 (mg/100 g)  \
# 1                                           < 0,16                   0,29
# 2                                              0,2                   0,12
# 3                                             0,88                  0,088
# 4                                             0,53                   0,14
# 5                                             0,26                  0,052
# ...                                            ...                    ...
# 3181                                          0,26                  0,029
# 3182                                          1,33                   0,38
# 3183                                          1,58                   0,29
# 3184                                          4,69                   0,66
# 3185                                          1,12                    0,3
#
#      Vitamine B9 ou Folates totaux (µg/100 g) Vitamine B12 (µg/100 g)
# 1                                          31                    1,45
# 2                                        11,1                    1,23
# 3                                        19,6                   0,018
# 4                                           7                       0
# 5                                        14,5                       0
# ...                                       ...                     ...
# 3181                                     9,06                     0,2
# 3182                                      100                    0,44
# 3183                                     86,5                    0,29
# 3184                                     31,1                    0,28
# 3185                                      117                    0,14
#
# [1258 rows x 76 columns]

# %% [markdown]
# <h4 style = "text-align: center;">Food Name Column ("alim_nom_fr")</h4>

# %%
# Check for duplicated food french names
duplicated_food_french_names_df = nutrition_cleaned_df[nutrition_cleaned_df.duplicated(subset = "alim_nom_fr", keep = False)]
pd.set_option("display.max_columns", None)
duplicated_food_french_names_df
# Out:
#       alim_grp_code  alim_ssgrp_code  alim_ssssgrp_code  \
# 3120             10             1009                  0
# 3121             10             1009                  0
#
#                              alim_grp_nom_fr  \
# 3120  aides culinaires et ingrédients divers
# 3121  aides culinaires et ingrédients divers
#
#                                      alim_ssgrp_nom_fr  \
# 3120  aides culinaires et ingrédients pour végétariens
# 3121                                ingrédients divers
#
#                    alim_ssssgrp_nom_fr  alim_code alim_nom_fr alim_nom_sci  \
# 3120  sous-sous-catégories non définie       9621  Son de blé          NaN
# 3121  sous-sous-catégories non définie       9621  Son de blé          NaN
#
#      Energie, Règlement UE N° 1169/2011 (kJ/100 g)  \
# 3120                                          1160
# 3121                                           NaN
#
#      Energie, Règlement UE N° 1169/2011 (kcal/100 g)  \
# 3120                                             NaN
# 3121                                             279
#
#      Energie, N x facteur Jones, avec fibres  (kJ/100 g)  \
# 3120                                                NaN
# 3121                                               1160
#
#      Energie, N x facteur Jones, avec fibres  (kcal/100 g) Eau (g/100 g)  \
# 3120                                                NaN              NaN
# 3121                                                279             9,05
#
#      Protéines, N x facteur de Jones (g/100 g) Protéines, N x 6.25 (g/100 g)  \
# 3120                                       NaN                           NaN
# 3121                                      15,4                          15,2
#
#      Glucides (g/100 g) Lipides (g/100 g) Sucres (g/100 g) Fructose (g/100 g)  \
# 3120                NaN               NaN              NaN                NaN
# 3121               23,6              4,35             2,46               0,49
#
#      Galactose (g/100 g) Glucose (g/100 g) Lactose (g/100 g)  \
# 3120                 NaN               NaN               NaN
# 3121                   -               0,5                 0
#
#      Maltose (g/100 g) Saccharose (g/100 g) Amidon (g/100 g)  \
# 3120               NaN                  NaN              NaN
# 3121                 0                 1,45             20,9
#
#      Fibres alimentaires (g/100 g) Polyols totaux (g/100 g) Cendres (g/100 g)  \
# 3120                           NaN                      NaN               NaN
# 3121                            42                        0               5,6
#
#      Alcool (g/100 g) Acides organiques (g/100 g) AG saturés (g/100 g)  \
# 3120              NaN                         NaN                  NaN
# 3121                0                           0                 0,84
#
#      AG monoinsaturés (g/100 g) AG polyinsaturés (g/100 g)  \
# 3120                        NaN                        NaN
# 3121                       0,67                       2,49
#
#      AG 4:0, butyrique (g/100 g) AG 6:0, caproïque (g/100 g)  \
# 3120                         NaN                         NaN
# 3121                           0                           0
#
#      AG 8:0, caprylique (g/100 g) AG 10:0, caprique (g/100 g)  \
# 3120                          NaN                         NaN
# 3121                            0                           0
#
#      AG 12:0, laurique (g/100 g) AG 14:0, myristique (g/100 g)  \
# 3120                         NaN                           NaN
# 3121                       0,002                         0,007
#
#      AG 16:0, palmitique (g/100 g) AG 18:0, stéarique (g/100 g)  \
# 3120                           NaN                          NaN
# 3121                          0,68                         0,04
#
#      AG 18:1 9c (n-9), oléique (g/100 g)  \
# 3120                                 NaN
# 3121                                0,66
#
#      AG 18:2 9c,12c (n-6), linoléique (g/100 g)  \
# 3120                                        NaN
# 3121                                       2,32
#
#      AG 18:3 c9,c12,c15 (n-3), alpha-linolénique (g/100 g)  \
# 3120                                                NaN
# 3121                                               0,16
#
#      AG 20:4 5c,8c,11c,14c (n-6), arachidonique (g/100 g)  \
# 3120                                                NaN
# 3121                                             0,0081
#
#      AG 20:5 5c,8c,11c,14c,17c (n-3) EPA (g/100 g)  \
# 3120                                           NaN
# 3121                                             0
#
#      AG 22:6 4c,7c,10c,13c,16c,19c (n-3) DHA (g/100 g) Cholestérol (mg/100 g)  \
# 3120                                               NaN                    NaN
# 3121                                                 0                      0
#
#      Sel chlorure de sodium (g/100 g) Calcium (mg/100 g) Chlorure (mg/100 g)  \
# 3120                              NaN                NaN                 NaN
# 3121                            0,033               73,9                   -
#
#      Cuivre (mg/100 g) Fer (mg/100 g) Iode (µg/100 g) Magnésium (mg/100 g)  \
# 3120               NaN            NaN             NaN                  NaN
# 3121              1,05           14,8             2,4                  546
#
#      Manganèse (mg/100 g) Phosphore (mg/100 g) Potassium (mg/100 g)  \
# 3120                  NaN                  NaN                  NaN
# 3121                 13,3                 1030                 1260
#
#      Sélénium (µg/100 g) Sodium (mg/100 g) Zinc (mg/100 g) Rétinol (µg/100 g)  \
# 3120                 NaN               NaN             NaN                NaN
# 3121                 6,8              13,3            7,49                  0
#
#      Beta-Carotène (µg/100 g) Vitamine D (µg/100 g) Vitamine E (mg/100 g)  \
# 3120                      NaN                   NaN                   NaN
# 3121                        6                     0                  1,55
#
#      Vitamine K1 (µg/100 g) Vitamine K2 (µg/100 g) Vitamine C (mg/100 g)  \
# 3120                    NaN                    NaN                   NaN
# 3121                   42,5                      -                     0
#
#      Vitamine B1 ou Thiamine (mg/100 g) Vitamine B2 ou Riboflavine (mg/100 g)  \
# 3120                                NaN                                   NaN
# 3121                               0,71                                  0,47
#
#      Vitamine B3 ou PP ou Niacine (mg/100 g)  \
# 3120                                     NaN
# 3121                                    21,6
#
#      Vitamine B5 ou Acide pantothénique (mg/100 g) Vitamine B6 (mg/100 g)  \
# 3120                                           NaN                    NaN
# 3121                                          2,29                   1,34
#
#      Vitamine B9 ou Folates totaux (µg/100 g) Vitamine B12 (µg/100 g)
# 3120                                      NaN                     NaN
# 3121                                      110                       0

# %%
# Fill missing data
nutrition_cleaned_df.iloc[3120, nutrition_cleaned_df.columns.get_loc("Energie, Règlement UE N° 1169/2011 (kJ/100 g)")] = 1160
nutrition_cleaned_df.iloc[[3118, 3119, 3120, 3122], :]
# Out:
#       alim_grp_code  alim_ssgrp_code  alim_ssssgrp_code  \
# 3119             10             1008                  0
# 3120             10             1009                  0
# 3121             10             1009                  0
# 3123             10             1009                  0
#
#                              alim_grp_nom_fr  \
# 3119  aides culinaires et ingrédients divers
# 3120  aides culinaires et ingrédients divers
# 3121  aides culinaires et ingrédients divers
# 3123  aides culinaires et ingrédients divers
#
#                                       alim_ssgrp_nom_fr  \
# 3119  denrées destinées à une alimentation particulière
# 3120   aides culinaires et ingrédients pour végétariens
# 3121                                 ingrédients divers
# 3123                                 ingrédients divers
#
#                    alim_ssssgrp_nom_fr  alim_code  \
# 3119  sous-sous-catégories non définie      42005
# 3120  sous-sous-catégories non définie       9621
# 3121  sous-sous-catégories non définie       9621
# 3123  sous-sous-catégories non définie       9641
#
#                                             alim_nom_fr alim_nom_sci  \
# 3119  Substitut de repas hypocalorique, poudre recon...          NaN
# 3120                                         Son de blé          NaN
# 3121                                         Son de blé          NaN
# 3123                                        Son de maïs          NaN
#
#      Energie, Règlement UE N° 1169/2011 (kJ/100 g)  \
# 3119                                           367
# 3120                                          1160
# 3121                                          1160
# 3123                                           921
#
#      Energie, Règlement UE N° 1169/2011 (kcal/100 g)  \
# 3119                                              87
# 3120                                             NaN
# 3121                                             279
# 3123                                             226
#
#      Energie, N x facteur Jones, avec fibres  (kJ/100 g)  \
# 3119                                                369
# 3120                                                NaN
# 3121                                               1160
# 3123                                                921
#
#      Energie, N x facteur Jones, avec fibres  (kcal/100 g) Eau (g/100 g)  \
# 3119                                               87,5               80
# 3120                                                NaN              NaN
# 3121                                                279             9,05
# 3123                                                226             4,71
#
#      Protéines, N x facteur de Jones (g/100 g) Protéines, N x 6.25 (g/100 g)  \
# 3119                                      6,19                          6,07
# 3120                                       NaN                           NaN
# 3121                                      15,4                          15,2
# 3123                                      8,36                          8,36
#
#      Glucides (g/100 g) Lipides (g/100 g) Sucres (g/100 g) Fructose (g/100 g)  \
# 3119               10,2              2,28               10                  -
# 3120                NaN               NaN              NaN                NaN
# 3121               23,6              4,35             2,46               0,49
# 3123               6,65              0,92                0                  -
#
#      Galactose (g/100 g) Glucose (g/100 g) Lactose (g/100 g)  \
# 3119                   -                 -                 -
# 3120                 NaN               NaN               NaN
# 3121                   -               0,5                 0
# 3123                   -                 -                 -
#
#      Maltose (g/100 g) Saccharose (g/100 g) Amidon (g/100 g)  \
# 3119                 -                    -              0,2
# 3120               NaN                  NaN              NaN
# 3121                 0                 1,45             20,9
# 3123                 -                    -                -
#
#      Fibres alimentaires (g/100 g) Polyols totaux (g/100 g) Cendres (g/100 g)  \
# 3119                          0,63                        0              0,77
# 3120                           NaN                      NaN               NaN
# 3121                            42                        0               5,6
# 3123                            79                        0              0,36
#
#      Alcool (g/100 g) Acides organiques (g/100 g) AG saturés (g/100 g)  \
# 3119                0                      traces                 0,28
# 3120              NaN                         NaN                  NaN
# 3121                0                           0                 0,84
# 3123                0                           0                 0,13
#
#      AG monoinsaturés (g/100 g) AG polyinsaturés (g/100 g)  \
# 3119                       0,66                       1,23
# 3120                        NaN                        NaN
# 3121                       0,67                       2,49
# 3123                       0,24                       0,42
#
#      AG 4:0, butyrique (g/100 g) AG 6:0, caproïque (g/100 g)  \
# 3119                           -                           -
# 3120                         NaN                         NaN
# 3121                           0                           0
# 3123                           0                           0
#
#      AG 8:0, caprylique (g/100 g) AG 10:0, caprique (g/100 g)  \
# 3119                            -                           -
# 3120                          NaN                         NaN
# 3121                            0                           0
# 3123                            0                           0
#
#      AG 12:0, laurique (g/100 g) AG 14:0, myristique (g/100 g)  \
# 3119                           -                             -
# 3120                         NaN                           NaN
# 3121                       0,002                         0,007
# 3123                           0                             0
#
#      AG 16:0, palmitique (g/100 g) AG 18:0, stéarique (g/100 g)  \
# 3119                             -                            -
# 3120                           NaN                          NaN
# 3121                          0,68                         0,04
# 3123                          0,11                        0,015
#
#      AG 18:1 9c (n-9), oléique (g/100 g)  \
# 3119                                   -
# 3120                                 NaN
# 3121                                0,66
# 3123                                   -
#
#      AG 18:2 9c,12c (n-6), linoléique (g/100 g)  \
# 3119                                        0,4
# 3120                                        NaN
# 3121                                       2,32
# 3123                                          -
#
#      AG 18:3 c9,c12,c15 (n-3), alpha-linolénique (g/100 g)  \
# 3119                                                  -
# 3120                                                NaN
# 3121                                               0,16
# 3123                                                  -
#
#      AG 20:4 5c,8c,11c,14c (n-6), arachidonique (g/100 g)  \
# 3119                                                  -
# 3120                                                NaN
# 3121                                             0,0081
# 3123                                                  -
#
#      AG 20:5 5c,8c,11c,14c,17c (n-3) EPA (g/100 g)  \
# 3119                                             -
# 3120                                           NaN
# 3121                                             0
# 3123                                             0
#
#      AG 22:6 4c,7c,10c,13c,16c,19c (n-3) DHA (g/100 g) Cholestérol (mg/100 g)  \
# 3119                                                 -                     10
# 3120                                               NaN                    NaN
# 3121                                                 0                      0
# 3123                                                 0                      0
#
#      Sel chlorure de sodium (g/100 g) Calcium (mg/100 g) Chlorure (mg/100 g)  \
# 3119                             0,19                172                   -
# 3120                              NaN                NaN                 NaN
# 3121                            0,033               73,9                   -
# 3123                            0,018                 42                   -
#
#      Cuivre (mg/100 g) Fer (mg/100 g) Iode (µg/100 g) Magnésium (mg/100 g)  \
# 3119              0,41           1,91              17                   28
# 3120               NaN            NaN             NaN                  NaN
# 3121              1,05           14,8             2,4                  546
# 3123              0,25           2,79               -                   64
#
#      Manganèse (mg/100 g) Phosphore (mg/100 g) Potassium (mg/100 g)  \
# 3119                  0,2                  138                  234
# 3120                  NaN                  NaN                  NaN
# 3121                 13,3                 1030                 1260
# 3123                 0,14                   72                   44
#
#      Sélénium (µg/100 g) Sodium (mg/100 g) Zinc (mg/100 g) Rétinol (µg/100 g)  \
# 3119                 7,8              77,3            3,13                 78
# 3120                 NaN               NaN             NaN                NaN
# 3121                 6,8              13,3            7,49                  0
# 3123                   -                 7            1,56                  0
#
#      Beta-Carotène (µg/100 g) Vitamine D (µg/100 g) Vitamine E (mg/100 g)  \
# 3119                        -                   0,7                  1,57
# 3120                      NaN                   NaN                   NaN
# 3121                        6                     0                  1,55
# 3123                       32                     0                  0,42
#
#      Vitamine K1 (µg/100 g) Vitamine K2 (µg/100 g) Vitamine C (mg/100 g)  \
# 3119                      -                      -                  6,78
# 3120                    NaN                    NaN                   NaN
# 3121                   42,5                      -                     0
# 3123                    0,3                      -                     0
#
#      Vitamine B1 ou Thiamine (mg/100 g) Vitamine B2 ou Riboflavine (mg/100 g)  \
# 3119                               0,17                                   0,2
# 3120                                NaN                                   NaN
# 3121                               0,71                                  0,47
# 3123                               0,01                                   0,1
#
#      Vitamine B3 ou PP ou Niacine (mg/100 g)  \
# 3119                                    2,83
# 3120                                     NaN
# 3121                                    21,6
# 3123                                    2,74
#
#      Vitamine B5 ou Acide pantothénique (mg/100 g) Vitamine B6 (mg/100 g)  \
# 3119                                           0,4                   0,33
# 3120                                           NaN                    NaN
# 3121                                          2,29                   1,34
# 3123                                          0,64                   0,15
#
#      Vitamine B9 ou Folates totaux (µg/100 g) Vitamine B12 (µg/100 g)
# 3119                                       36                    0,34
# 3120                                      NaN                     NaN
# 3121                                      110                       0
# 3123                                        4                       0

# %%
# Drop the duplicated row
pd.reset_option("display.max_columns")
nutrition_cleaned_df.drop(index = 3120, inplace = True)
nutrition_cleaned_df.reset_index(drop = True, inplace = True)
nutrition_cleaned_df.iloc[[3118, 3119, 3120], :]
# Out:
#       alim_grp_code  alim_ssgrp_code  alim_ssssgrp_code  \
# 3118             10             1008                  0
# 3119             10             1009                  0
# 3120             10             1009                  0
#
#                              alim_grp_nom_fr  \
# 3118  aides culinaires et ingrédients divers
# 3119  aides culinaires et ingrédients divers
# 3120  aides culinaires et ingrédients divers
#
#                                       alim_ssgrp_nom_fr  \
# 3118  denrées destinées à une alimentation particulière
# 3119                                 ingrédients divers
# 3120                                 ingrédients divers
#
#                    alim_ssssgrp_nom_fr  alim_code  \
# 3118  sous-sous-catégories non définie      42005
# 3119  sous-sous-catégories non définie       9621
# 3120  sous-sous-catégories non définie       9640
#
#                                             alim_nom_fr alim_nom_sci  \
# 3118  Substitut de repas hypocalorique, poudre recon...          NaN
# 3119                                         Son de blé          NaN
# 3120                                       Son d'avoine          NaN
#
#      Energie, Règlement UE N° 1169/2011 (kJ/100 g)  ...  \
# 3118                                           367  ...
# 3119                                          1160  ...
# 3120                                          1510  ...
#
#      Vitamine K1 (µg/100 g) Vitamine K2 (µg/100 g) Vitamine C (mg/100 g)  \
# 3118                      -                      -                  6,78
# 3119                   42,5                      -                     0
# 3120                    3,2                      -                     0
#
#      Vitamine B1 ou Thiamine (mg/100 g) Vitamine B2 ou Riboflavine (mg/100 g)  \
# 3118                               0,17                                   0,2
# 3119                               0,71                                  0,47
# 3120                               1,17                                  0,22
#
#      Vitamine B3 ou PP ou Niacine (mg/100 g)  \
# 3118                                    2,83
# 3119                                    21,6
# 3120                                    0,93
#
#      Vitamine B5 ou Acide pantothénique (mg/100 g) Vitamine B6 (mg/100 g)  \
# 3118                                           0,4                   0,33
# 3119                                          2,29                   1,34
# 3120                                          1,49                   0,17
#
#      Vitamine B9 ou Folates totaux (µg/100 g) Vitamine B12 (µg/100 g)
# 3118                                       36                    0,34
# 3119                                      110                       0
# 3120                                       52                       0
#
# [3 rows x 76 columns]

# %% [markdown]
# <h4 style = "text-align: center;">Food Scientific Name Column ("alim_nom_sci")</h4>

# %%
# Drop the column of scientific names
nutrition_cleaned_df.drop(columns = ["alim_nom_sci"], inplace = True)

# %% [markdown]
# <h4 style = "text-align: center;">Nutrients Columns</h4>

# %%
# Store the columns containing nutritional values in a list
nutritional_columns_list = [
    "Energie, Règlement UE N° 1169/2011 (kJ/100 g)",
    "Energie, Règlement UE N° 1169/2011 (kcal/100 g)",
    "Energie, N x facteur Jones, avec fibres  (kJ/100 g)",
    "Energie, N x facteur Jones, avec fibres  (kcal/100 g)",
    "Eau (g/100 g)",
    "Protéines, N x facteur de Jones (g/100 g)",
    "Protéines, N x 6.25 (g/100 g)",
    "Glucides (g/100 g)",
    "Lipides (g/100 g)",
    "Sucres (g/100 g)",
    "Fructose (g/100 g)",
    "Galactose (g/100 g)",
    "Glucose (g/100 g)",
    "Lactose (g/100 g)",
    "Maltose (g/100 g)",
    "Saccharose (g/100 g)",
    "Amidon (g/100 g)",
    "Fibres alimentaires (g/100 g)",
    "Polyols totaux (g/100 g)",
    "Cendres (g/100 g)",
    "Alcool (g/100 g)",
    "Acides organiques (g/100 g)",
    "AG saturés (g/100 g)",
    "AG monoinsaturés (g/100 g)",
    "AG polyinsaturés (g/100 g)",
    "AG 4:0, butyrique (g/100 g)",
    "AG 6:0, caproïque (g/100 g)",
    "AG 8:0, caprylique (g/100 g)",
    "AG 10:0, caprique (g/100 g)",
    "AG 12:0, laurique (g/100 g)",
    "AG 14:0, myristique (g/100 g)",
    "AG 16:0, palmitique (g/100 g)",
    "AG 18:0, stéarique (g/100 g)",
    "AG 18:1 9c (n-9), oléique (g/100 g)",
    "AG 18:2 9c,12c (n-6), linoléique (g/100 g)",
    "AG 18:3 c9,c12,c15 (n-3), alpha-linolénique (g/100 g)",
    "AG 20:4 5c,8c,11c,14c (n-6), arachidonique (g/100 g)",
    "AG 20:5 5c,8c,11c,14c,17c (n-3) EPA (g/100 g)",
    "AG 22:6 4c,7c,10c,13c,16c,19c (n-3) DHA (g/100 g)",
    "Cholestérol (mg/100 g)",
    "Sel chlorure de sodium (g/100 g)",
    "Calcium (mg/100 g)",
    "Chlorure (mg/100 g)",
    "Cuivre (mg/100 g)",
    "Fer (mg/100 g)",
    "Iode (µg/100 g)",
    "Magnésium (mg/100 g)",
    "Manganèse (mg/100 g)",
    "Phosphore (mg/100 g)",
    "Potassium (mg/100 g)",
    "Sélénium (µg/100 g)",
    "Sodium (mg/100 g)",
    "Zinc (mg/100 g)",
    "Rétinol (µg/100 g)",
    "Beta-Carotène (µg/100 g)",
    "Vitamine D (µg/100 g)",
    "Vitamine E (mg/100 g)",
    "Vitamine K1 (µg/100 g)",
    "Vitamine K2 (µg/100 g)",
    "Vitamine C (mg/100 g)",
    "Vitamine B1 ou Thiamine (mg/100 g)",
    "Vitamine B2 ou Riboflavine (mg/100 g)",
    "Vitamine B3 ou PP ou Niacine (mg/100 g)",
    "Vitamine B5 ou Acide pantothénique (mg/100 g)",
    "Vitamine B6 (mg/100 g)",
    "Vitamine B9 ou Folates totaux (µg/100 g)",
    "Vitamine B12 (µg/100 g)"
]

# Iterate through the columns containing nutritional values to format the type to numeric 
for column_name in nutritional_columns_list:
    if column_name in nutrition_cleaned_df.columns:
        nutrition_cleaned_df[column_name] = pd.to_numeric(nutrition_cleaned_df[column_name], errors = "coerce")

# Handle missing values
nutrition_cleaned_df.replace("", pd.NA, inplace = True)

# %% [markdown]
# <h3 style = "text-align: center;">Check(s)</h3>

# %%
# Check the unique names of the groups, sub-groups and sub-sub-groups
cleaned_alim_grp_nom_fr_list = nutrition_cleaned_df["alim_grp_nom_fr"].unique().tolist()
print("NAME OF THE FOOD GROUPS")
print(cleaned_alim_grp_nom_fr_list)
print()

cleaned_alim_ssgrp_nom_fr_list = nutrition_cleaned_df["alim_ssgrp_nom_fr"].unique().tolist()
print("NAME OF THE FOOD SUB-GROUPS")
print(cleaned_alim_ssgrp_nom_fr_list)
print()

cleaned_alim_ssssgrp_nom_fr_list = nutrition_cleaned_df["alim_ssssgrp_nom_fr"].unique().tolist()
print("NAME OF THE FOOD SUB-SUB-GROUPS")
print(cleaned_alim_ssssgrp_nom_fr_list)
print()
# Out:
# NAME OF THE FOOD GROUPS
# ['entrées et plats composés', 'fruits, légumes, légumineuses et oléagineux', 'produits céréaliers', 'farines, amidons et bases de pâtes', 'viandes, œufs, poissons et assimilés', 'produits laitiers et assimilés', 'eaux et autres boissons', 'produits sucrés', 'glaces et sorbets', 'matières grasses', 'aides culinaires et ingrédients divers', 'aliments infantiles']
#
# NAME OF THE FOOD SUB-GROUPS
# ['salades composées et crudités', 'soupes', 'plats composés', 'pizzas, tartes et crêpes salées', 'sandwichs', 'feuilletées et autres entrées', 'légumes', 'pommes de terre et autres tubercules', 'légumineuses', 'fruits', 'fruits à coque et graines oléagineuses', 'pâtes, riz et céréales', 'pains et assimilés', 'biscuits apéritifs', 'amidons', 'farines', 'bases de pâtes', 'viandes cuites', 'viandes crues', 'charcuteries et assimilés', 'autres produits à base de viande', 'poissons cuits', 'poissons crus', 'mollusques et crustacés cuits', 'mollusques et crustacés crus', 'produits à base de poissons et produits de la mer', 'œufs', 'substitus de produits carnés', 'laits', 'produits laitiers frais et assimilés', 'fromages et assimilés', 'crèmes et spécialités à base de crème', 'eaux', 'boissons sans alcool', 'boisson alcoolisées', 'sucres, miels et assimilés', 'chocolats et produits à base de chocolat', 'confiseries non chocolatées', 'confitures et assimilés', 'viennoiseries', 'biscuits sucrés', 'céréales de petit-déjeuner', 'barres céréalières', 'gâteaux et pâtisseries', 'glaces et sorbets', 'glaces', 'sorbets', 'desserts glacés', 'beurres', 'huiles et graisses végétales', 'margarines', 'huiles de poissons', 'autres matières grasses', 'sauces', 'condiments', 'aides culinaires', 'sels', 'épices', 'herbes', 'algues', 'denrées destinées à une alimentation particulière', 'ingrédients divers', 'laits et boissons infantiles', 'petits pots salés et plats infantiles', 'desserts infantiles', 'céréales et biscuits infantiles']
#
# NAME OF THE FOOD SUB-SUB-GROUPS
# ['sous-sous-catégories non définie', 'plats de viande sans garniture', 'plats de viande et féculents', 'plats de viande et légumes/légumineuses', 'plats de poisson sans garniture', 'plats de poisson et féculents', 'plats de légumes/légumineuses', 'plats de céréales/pâtes', 'plats de fromage', 'plats végétariens', 'légumes crus', 'légumes cuits', 'légumes séchés ou déshydratés', 'légumes et leurs produits de la Martinique', 'légumes et leurs produits de la Réunion', 'légumineuses cuites', 'légumineuses fraîches', 'légumineuses sèches', 'fruits crus', 'compotes et assimilés', 'fruits appertisés', 'fruits séchés', 'fruits et leurs produits de la Martinique', 'fruits et leurs produits de la Réunion', 'pâtes, riz et céréales cuits', 'pâtes, riz et céréales crus', 'pains', 'biscottes et pains grillés', 'amidons', 'farines', 'bases de pâtes', 'bœuf et veau', 'porc', 'poulet', 'dinde', 'agneau et mouton', 'gibier', 'autres viandes', 'abats', 'jambons cuits', 'jambons secs et crus', 'saucisson secs', 'saucisses et assimilés', 'pâtés et terrines', 'rillettes', 'quenelles', 'autres spécialités charcutières', 'substituts de charcuteries pour végétariens', 'œufs cuits', 'œufs crus', 'omelettes et autres ovoproduits', 'laits de vaches liquides (non concentrés)', 'laits autres que de vache', 'laits de vache concentrés ou en poudre', 'yaourts et spécialités laitières type yaourt', 'fromages blancs', 'desserts lactés', 'autres desserts', 'desserts végétaux', 'fromages à pâte molle', 'fromages à pâte persillée', 'fromages à pâte pressée', 'fromage fondus', 'autres fromages et spécialités', 'substituts de fromages pour végétariens', 'jus', 'nectars', 'boissons rafraîchissantes sans alcool', 'boissons rafraîchissantes lactées', 'boissons végétales', 'café, thé, cacao etc. prêts à consommer', 'boissons à reconstituer', 'vins', 'bières et cidres', 'liqueurs et alcools', 'cocktails', 'glaces et sorbets', 'sauces condimentaires', 'sauces chaudes', 'sauces sucrées', 'herbes fraîches', 'herbes séchées']

# %%
# Check the dataframe
check_dataframe(nutrition_cleaned_df)
# Out:
# GENERAL INFORMATION
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3184 entries, 0 to 3183
# Data columns (total 75 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   alim_grp_code                                          3184 non-null   int64
#  1   alim_ssgrp_code                                        3184 non-null   int64
#  2   alim_ssssgrp_code                                      3184 non-null   int64
#  3   alim_grp_nom_fr                                        3184 non-null   object
#  4   alim_ssgrp_nom_fr                                      3184 non-null   object
#  5   alim_ssssgrp_nom_fr                                    3184 non-null   object
#  6   alim_code                                              3184 non-null   int64
#  7   alim_nom_fr                                            3184 non-null   object
#  8   Energie, Règlement UE N° 1169/2011 (kJ/100 g)          2233 non-null   float64
#  9   Energie, Règlement UE N° 1169/2011 (kcal/100 g)        1770 non-null   float64
#  10  Energie, N x facteur Jones, avec fibres  (kJ/100 g)    2234 non-null   float64
#  11  Energie, N x facteur Jones, avec fibres  (kcal/100 g)  1764 non-null   float64
#  12  Eau (g/100 g)                                          368 non-null    float64
#  13  Protéines, N x facteur de Jones (g/100 g)              395 non-null    float64
#  14  Protéines, N x 6.25 (g/100 g)                          422 non-null    float64
#  15  Glucides (g/100 g)                                     540 non-null    float64
#  16  Lipides (g/100 g)                                      428 non-null    float64
#  17  Sucres (g/100 g)                                       723 non-null    float64
#  18  Fructose (g/100 g)                                     212 non-null    float64
#  19  Galactose (g/100 g)                                    200 non-null    float64
#  20  Glucose (g/100 g)                                      214 non-null    float64
#  21  Lactose (g/100 g)                                      348 non-null    float64
#  22  Maltose (g/100 g)                                      286 non-null    float64
#  23  Saccharose (g/100 g)                                   236 non-null    float64
#  24  Amidon (g/100 g)                                       864 non-null    float64
#  25  Fibres alimentaires (g/100 g)                          1228 non-null   float64
#  26  Polyols totaux (g/100 g)                               2034 non-null   float64
#  27  Cendres (g/100 g)                                      76 non-null     float64
#  28  Alcool (g/100 g)                                       3111 non-null   float64
#  29  Acides organiques (g/100 g)                            1167 non-null   float64
#  30  AG saturés (g/100 g)                                   278 non-null    float64
#  31  AG monoinsaturés (g/100 g)                             192 non-null    float64
#  32  AG polyinsaturés (g/100 g)                             187 non-null    float64
#  33  AG 4:0, butyrique (g/100 g)                            588 non-null    float64
#  34  AG 6:0, caproïque (g/100 g)                            588 non-null    float64
#  35  AG 8:0, caprylique (g/100 g)                           569 non-null    float64
#  36  AG 10:0, caprique (g/100 g)                            501 non-null    float64
#  37  AG 12:0, laurique (g/100 g)                            405 non-null    float64
#  38  AG 14:0, myristique (g/100 g)                          193 non-null    float64
#  39  AG 16:0, palmitique (g/100 g)                          58 non-null     float64
#  40  AG 18:0, stéarique (g/100 g)                           69 non-null     float64
#  41  AG 18:1 9c (n-9), oléique (g/100 g)                    40 non-null     float64
#  42  AG 18:2 9c,12c (n-6), linoléique (g/100 g)             36 non-null     float64
#  43  AG 18:3 c9,c12,c15 (n-3), alpha-linolénique (g/100 g)  46 non-null     float64
#  44  AG 20:4 5c,8c,11c,14c (n-6), arachidonique (g/100 g)   178 non-null    float64
#  45  AG 20:5 5c,8c,11c,14c,17c (n-3) EPA (g/100 g)          572 non-null    float64
#  46  AG 22:6 4c,7c,10c,13c,16c,19c (n-3) DHA (g/100 g)      547 non-null    float64
#  47  Cholestérol (mg/100 g)                                 1359 non-null   float64
#  48  Sel chlorure de sodium (g/100 g)                       72 non-null     float64
#  49  Calcium (mg/100 g)                                     1554 non-null   float64
#  50  Chlorure (mg/100 g)                                    931 non-null    float64
#  51  Cuivre (mg/100 g)                                      62 non-null     float64
#  52  Fer (mg/100 g)                                         137 non-null    float64
#  53  Iode (µg/100 g)                                        654 non-null    float64
#  54  Magnésium (mg/100 g)                                   1286 non-null   float64
#  55  Manganèse (mg/100 g)                                   62 non-null     float64
#  56  Phosphore (mg/100 g)                                   2050 non-null   float64
#  57  Potassium (mg/100 g)                                   2236 non-null   float64
#  58  Sélénium (µg/100 g)                                    301 non-null    float64
#  59  Sodium (mg/100 g)                                      2079 non-null   float64
#  60  Zinc (mg/100 g)                                        118 non-null    float64
#  61  Rétinol (µg/100 g)                                     1446 non-null   float64
#  62  Beta-Carotène (µg/100 g)                               1342 non-null   float64
#  63  Vitamine D (µg/100 g)                                  787 non-null    float64
#  64  Vitamine E (mg/100 g)                                  257 non-null    float64
#  65  Vitamine K1 (µg/100 g)                                 353 non-null    float64
#  66  Vitamine K2 (µg/100 g)                                 6 non-null      float64
#  67  Vitamine C (mg/100 g)                                  805 non-null    float64
#  68  Vitamine B1 ou Thiamine (mg/100 g)                     166 non-null    float64
#  69  Vitamine B2 ou Riboflavine (mg/100 g)                  153 non-null    float64
#  70  Vitamine B3 ou PP ou Niacine (mg/100 g)                203 non-null    float64
#  71  Vitamine B5 ou Acide pantothénique (mg/100 g)          173 non-null    float64
#  72  Vitamine B6 (mg/100 g)                                 169 non-null    float64
#  73  Vitamine B9 ou Folates totaux (µg/100 g)               1174 non-null   float64
#  74  Vitamine B12 (µg/100 g)                                778 non-null    float64
# dtypes: float64(67), int64(4), object(4)
# memory usage: 1.8+ MB
# None
#
# FIRST ROWS
#    alim_grp_code  alim_ssgrp_code  alim_ssssgrp_code  \
# 0              1              101                  0
# 1              1              101                  0
# 2              1              101                  0
# 3              1              101                  0
# 4              1              101                  0
#
#              alim_grp_nom_fr              alim_ssgrp_nom_fr  \
# 0  entrées et plats composés  salades composées et crudités
# 1  entrées et plats composés  salades composées et crudités
# 2  entrées et plats composés  salades composées et crudités
# 3  entrées et plats composés  salades composées et crudités
# 4  entrées et plats composés  salades composées et crudités
#
#                 alim_ssssgrp_nom_fr  alim_code  \
# 0  sous-sous-catégories non définie      25601
# 1  sous-sous-catégories non définie      25602
# 2  sous-sous-catégories non définie      25605
# 3  sous-sous-catégories non définie      25606
# 4  sous-sous-catégories non définie      25608
#
#                                          alim_nom_fr  \
# 0              Salade de thon et légumes, appertisée
# 1  Salade composée avec viande ou poisson, appert...
# 2               Champignons à la grecque, appertisés
# 3             Salade de pommes de terre, fait maison
# 4          Taboulé ou Salade de couscous, préemballé
#
#    Energie, Règlement UE N° 1169/2011 (kJ/100 g)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                          753.0
#
#    Energie, Règlement UE N° 1169/2011 (kcal/100 g)  ...  \
# 0                                              NaN  ...
# 1                                              NaN  ...
# 2                                              NaN  ...
# 3                                              NaN  ...
# 4                                            179.0  ...
#
#    Vitamine K1 (µg/100 g)  Vitamine K2 (µg/100 g)  Vitamine C (mg/100 g)  \
# 0                     NaN                     NaN                    NaN
# 1                     NaN                     NaN                    NaN
# 2                     NaN                     NaN                    NaN
# 3                     NaN                     NaN                   10.0
# 4                     NaN                     NaN                    NaN
#
#    Vitamine B1 ou Thiamine (mg/100 g)  Vitamine B2 ou Riboflavine (mg/100 g)  \
# 0                                 NaN                                    NaN
# 1                                 NaN                                    NaN
# 2                                 NaN                                    NaN
# 3                                 NaN                                    NaN
# 4                                 NaN                                    NaN
#
#    Vitamine B3 ou PP ou Niacine (mg/100 g)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    Vitamine B5 ou Acide pantothénique (mg/100 g)  Vitamine B6 (mg/100 g)  \
# 0                                            NaN                     NaN
# 1                                            NaN                     NaN
# 2                                            NaN                     NaN
# 3                                            NaN                     NaN
# 4                                            NaN                     NaN
#
#    Vitamine B9 ou Folates totaux (µg/100 g)  Vitamine B12 (µg/100 g)
# 0                                      31.0                      NaN
# 1                                       NaN                      NaN
# 2                                       NaN                      NaN
# 3                                       7.0                      0.0
# 4                                       NaN                      0.0
#
# [5 rows x 75 columns]
#
# LAST ROWS
#       alim_grp_code  alim_ssgrp_code  alim_ssssgrp_code      alim_grp_nom_fr  \
# 3179             11             1103                  0  aliments infantiles
# 3180             11             1104                  0  aliments infantiles
# 3181             11             1104                  0  aliments infantiles
# 3182             11             1104                  0  aliments infantiles
# 3183             11             1104                  0  aliments infantiles
#
#                     alim_ssgrp_nom_fr               alim_ssssgrp_nom_fr  \
# 3179              desserts infantiles  sous-sous-catégories non définie
# 3180  céréales et biscuits infantiles  sous-sous-catégories non définie
# 3181  céréales et biscuits infantiles  sous-sous-catégories non définie
# 3182  céréales et biscuits infantiles  sous-sous-catégories non définie
# 3183  céréales et biscuits infantiles  sous-sous-catégories non définie
#
#       alim_code                                        alim_nom_fr  \
# 3179      13166  Dessert lacté infantile nature sucré ou aux fr...
# 3180      13167  Céréales instantanées, poudre à reconstituer, ...
# 3181      13168  Céréales instantanées, poudre à reconstituer, ...
# 3182      24689                                  Biscuit pour bébé
# 3183      42501                          Poudre cacaotée pour bébé
#
#       Energie, Règlement UE N° 1169/2011 (kJ/100 g)  \
# 3179                                          420.0
# 3180                                         1670.0
# 3181                                         1660.0
# 3182                                         1850.0
# 3183                                         1680.0
#
#       Energie, Règlement UE N° 1169/2011 (kcal/100 g)  ...  \
# 3179                                            100.0  ...
# 3180                                            393.0  ...
# 3181                                            391.0  ...
# 3182                                            439.0  ...
# 3183                                            396.0  ...
#
#       Vitamine K1 (µg/100 g)  Vitamine K2 (µg/100 g)  Vitamine C (mg/100 g)  \
# 3179                     NaN                     NaN                    NaN
# 3180                     NaN                     NaN                    NaN
# 3181                     NaN                     NaN                    NaN
# 3182                     NaN                     NaN                    NaN
# 3183                     NaN                     NaN                    NaN
#
#       Vitamine B1 ou Thiamine (mg/100 g)  \
# 3179                                 NaN
# 3180                                 NaN
# 3181                                 NaN
# 3182                                 NaN
# 3183                                 NaN
#
#       Vitamine B2 ou Riboflavine (mg/100 g)  \
# 3179                                    NaN
# 3180                                    NaN
# 3181                                    NaN
# 3182                                    NaN
# 3183                                    NaN
#
#       Vitamine B3 ou PP ou Niacine (mg/100 g)  \
# 3179                                      NaN
# 3180                                      NaN
# 3181                                      NaN
# 3182                                      NaN
# 3183                                      NaN
#
#       Vitamine B5 ou Acide pantothénique (mg/100 g)  Vitamine B6 (mg/100 g)  \
# 3179                                            NaN                     NaN
# 3180                                            NaN                     NaN
# 3181                                            NaN                     NaN
# 3182                                            NaN                     NaN
# 3183                                            NaN                     NaN
#
#       Vitamine B9 ou Folates totaux (µg/100 g)  Vitamine B12 (µg/100 g)
# 3179                                       NaN                      NaN
# 3180                                     100.0                      NaN
# 3181                                       NaN                      NaN
# 3182                                       NaN                      NaN
# 3183                                     117.0                      NaN
#
# [5 rows x 75 columns]
#
# DUPLICATED ROWS
# Count of duplicated rows: 0
#
# MISSING VALUES BY COLUMN
#                                       column_name  missing_values_count
# 0                                   alim_grp_code                     0
# 1                                 alim_ssgrp_code                     0
# 2                               alim_ssssgrp_code                     0
# 3                                 alim_grp_nom_fr                     0
# 4                               alim_ssgrp_nom_fr                     0
# ..                                            ...                   ...
# 70        Vitamine B3 ou PP ou Niacine (mg/100 g)                  2981
# 71  Vitamine B5 ou Acide pantothénique (mg/100 g)                  3011
# 72                         Vitamine B6 (mg/100 g)                  3015
# 73       Vitamine B9 ou Folates totaux (µg/100 g)                  2010
# 74                        Vitamine B12 (µg/100 g)                  2406
#
# [75 rows x 2 columns]
#
# UNIQUE VALUES BY COLUMN
#                                       column_name  unique_values_count
# 0                                   alim_grp_code                   11
# 1                                 alim_ssgrp_code                   64
# 2                               alim_ssssgrp_code                   88
# 3                                 alim_grp_nom_fr                   12
# 4                               alim_ssgrp_nom_fr                   66
# ..                                            ...                  ...
# 70        Vitamine B3 ou PP ou Niacine (mg/100 g)                   20
# 71  Vitamine B5 ou Acide pantothénique (mg/100 g)                    7
# 72                         Vitamine B6 (mg/100 g)                    2
# 73       Vitamine B9 ou Folates totaux (µg/100 g)                  213
# 74                        Vitamine B12 (µg/100 g)                   18
#
# [75 rows x 2 columns]
#
# STATISTICS
#         alim_grp_code  alim_ssgrp_code  alim_ssssgrp_code  \
# count     3184.000000      3184.000000        3184.000000
# unique            NaN              NaN                NaN
# top               NaN              NaN                NaN
# freq              NaN              NaN                NaN
# mean         4.443153       447.366834       23220.513505
# std          2.576734       258.070363       24798.460449
# min          1.000000         0.000000           0.000000
# 25%          2.000000       204.000000           0.000000
# 50%          4.000000       403.000000       20102.000000
# 75%          6.000000       602.000000       40208.000000
# max         11.000000      1104.000000      100602.000000
#
#                              alim_grp_nom_fr alim_ssgrp_nom_fr  \
# count                                   3184              3184
# unique                                    12                66
# top     viandes, œufs, poissons et assimilés           légumes
# freq                                     788               303
# mean                                     NaN               NaN
# std                                      NaN               NaN
# min                                      NaN               NaN
# 25%                                      NaN               NaN
# 50%                                      NaN               NaN
# 75%                                      NaN               NaN
# max                                      NaN               NaN
#
#                      alim_ssssgrp_nom_fr     alim_code  \
# count                               3184   3184.000000
# unique                                82           NaN
# top     sous-sous-catégories non définie           NaN
# freq                                1257           NaN
# mean                                 NaN  21351.458229
# std                                  NaN  13088.145369
# min                                  NaN   1000.000000
# 25%                                  NaN  12725.750000
# 50%                                  NaN  20220.000000
# 75%                                  NaN  26023.250000
# max                                  NaN  96781.000000
#
#                                   alim_nom_fr  \
# count                                    3184
# unique                                   3184
# top     Salade de thon et légumes, appertisée
# freq                                        1
# mean                                      NaN
# std                                       NaN
# min                                       NaN
# 25%                                       NaN
# 50%                                       NaN
# 75%                                       NaN
# max                                       NaN
#
#         Energie, Règlement UE N° 1169/2011 (kJ/100 g)  \
# count                                     2233.000000
# unique                                            NaN
# top                                               NaN
# freq                                              NaN
# mean                                       884.923421
# std                                        686.618668
# min                                          0.000000
# 25%                                        392.000000
# 50%                                        731.000000
# 75%                                       1230.000000
# max                                       3700.000000
#
#         Energie, Règlement UE N° 1169/2011 (kcal/100 g)  ...  \
# count                                       1770.000000  ...
# unique                                              NaN  ...
# top                                                 NaN  ...
# freq                                                NaN  ...
# mean                                         251.141808  ...
# std                                          164.632848  ...
# min                                            0.000000  ...
# 25%                                          141.000000  ...
# 50%                                          224.000000  ...
# 75%                                          339.750000  ...
# max                                          901.000000  ...
#
#         Vitamine K1 (µg/100 g)  Vitamine K2 (µg/100 g)  Vitamine C (mg/100 g)  \
# count               353.000000                6.000000             805.000000
# unique                     NaN                     NaN                    NaN
# top                        NaN                     NaN                    NaN
# freq                       NaN                     NaN                    NaN
# mean                 66.569405               73.166667              14.173913
# std                 226.742235              145.280992             107.113877
# min                   0.000000                0.000000               0.000000
# 25%                   0.000000               10.500000               0.000000
# 50%                   0.000000               15.000000               0.000000
# 75%                   4.000000               27.000000               4.000000
# max                1710.000000              369.000000            2850.000000
#
#         Vitamine B1 ou Thiamine (mg/100 g)  \
# count                           166.000000
# unique                                 NaN
# top                                    NaN
# freq                                   NaN
# mean                              0.078313
# std                               0.859816
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               0.000000
# max                              11.000000
#
#         Vitamine B2 ou Riboflavine (mg/100 g)  \
# count                              153.000000
# unique                                    NaN
# top                                       NaN
# freq                                      NaN
# mean                                 0.032680
# std                                  0.332817
# min                                  0.000000
# 25%                                  0.000000
# 50%                                  0.000000
# 75%                                  0.000000
# max                                  4.000000
#
#         Vitamine B3 ou PP ou Niacine (mg/100 g)  \
# count                                203.000000
# unique                                      NaN
# top                                         NaN
# freq                                        NaN
# mean                                   2.275862
# std                                    8.532568
# min                                    0.000000
# 25%                                    0.000000
# 50%                                    0.000000
# 75%                                    0.000000
# max                                  105.000000
#
#         Vitamine B5 ou Acide pantothénique (mg/100 g)  Vitamine B6 (mg/100 g)  \
# count                                      173.000000              169.000000
# unique                                            NaN                     NaN
# top                                               NaN                     NaN
# freq                                              NaN                     NaN
# mean                                         1.023121                0.017751
# std                                         10.143135                0.132439
# min                                          0.000000                0.000000
# 25%                                          0.000000                0.000000
# 50%                                          0.000000                0.000000
# 75%                                          0.000000                0.000000
# max                                        133.000000                1.000000
#
#         Vitamine B9 ou Folates totaux (µg/100 g)  Vitamine B12 (µg/100 g)
# count                                1174.000000               778.000000
# unique                                       NaN                      NaN
# top                                          NaN                      NaN
# freq                                         NaN                      NaN
# mean                                   54.747019                 0.795630
# std                                   142.357372                 6.978779
# min                                     0.000000                 0.000000
# 25%                                     5.000000                 0.000000
# 50%                                    16.000000                 0.000000
# 75%                                    43.000000                 0.000000
# max                                  2340.000000               150.000000
#
# [11 rows x 75 columns]

# %% [markdown]
# <h3 style = "text-align: center;">Comment(s)</h3>

# %% [markdown]
# <ul>
#     <li>Irrelevant column
#         <ul>Drop of Column "alim_nom_sci"</ul>
#     </li>
#     <br>
#     <li>Duplicated rows
#         <ul>No duplicated rows but Merge of 2 rows in Column "alim_nom_fr"</ul>
#     </li>
#     <br>
#     <li>Missing values
#         <ul>Manual fill of missing values in Column "alim_grp_nom_fr"</ul>
#         <ul>Manual fill of missing values in Column "alim_ssgrp_nom_fr"</ul>
#         <ul>Manual fill of missing values in Column "alim_ssssgrp_nom_fr"</ul>
#     </li>
#     <br>
#     <li>Data formats
#         <ul>No formatting</ul>
#     </li>
#     <br>
#     <li>Data types
#         <ul>Conversion of values in Nutrients Columns to numeric</ul>
#     </li>
#     <br>
#     <li>Additional Features
#         <ul>No additional features</ul>
#     </li>
# </ul>

# %% [markdown]
# <h2 style = "text-align: center;"><em>Data Wrangling</em></h2>

# %% [markdown]
# <h3 style = "text-align: center;">CSV Export </h3>

# %%
# Split the dataframe into food content categories and Prepare the columns for SQL

# Store the Macro-nutrients
macro_nutrients_df = nutrition_cleaned_df[[
    "alim_nom_fr",
    "Energie, Règlement UE N° 1169/2011 (kJ/100 g)",
    "Energie, Règlement UE N° 1169/2011 (kcal/100 g)",
    "Energie, N x facteur Jones, avec fibres  (kJ/100 g)",
    "Energie, N x facteur Jones, avec fibres  (kcal/100 g)",
    "Protéines, N x facteur de Jones (g/100 g)",
    "Glucides (g/100 g)",                                                  
    "Lipides (g/100 g)",
    "Eau (g/100 g)"
]]
macro_nutrients_df = macro_nutrients_df.rename(columns = {
    "alim_nom_fr": "food_name_in_french",
    "Energie, Règlement UE N° 1169/2011 (kJ/100 g)": "energy_in_kJ_for_100g",
    "Energie, Règlement UE N° 1169/2011 (kcal/100 g)": "energy_in_kcal_for_100g",
    "Energie, N x facteur Jones, avec fibres  (kJ/100 g)": "energy_with_jones_and_fibers_in_kJ_for_100g",
    "Energie, N x facteur Jones, avec fibres  (kcal/100 g)": "energy_with_jones_and_fibers_in_kcal_for_100g",
    "Protéines, N x facteur de Jones (g/100 g)": "proteins_with_jones_in_g_for_100g",
    "Glucides (g/100 g)": "carbohydrates_in_g_for_100g",
    "Lipides (g/100 g)": "fats_in_g_for_100g",
    "Eau (g/100 g)": "water_in_g_for_100g"
})


# Store the Carbohydrates
carbs_df = nutrition_cleaned_df[[
    "alim_nom_fr",
    "Sucres (g/100 g)",
    "Fructose (g/100 g)",
    "Galactose (g/100 g)",
    "Glucose (g/100 g)",
    "Lactose (g/100 g)",
    "Maltose (g/100 g)",
    "Saccharose (g/100 g)",
    "Amidon (g/100 g)",
    "Fibres alimentaires (g/100 g)",
    "Polyols totaux (g/100 g)"
]]
carbs_df = carbs_df.rename(columns = {
    "alim_nom_fr": "food_name_in_french",
    "Sucres (g/100 g)": "sugars_in_g_for_100g",
    "Fructose (g/100 g)": "fructose_in_g_for_100g",
    "Galactose (g/100 g)": "galactose_in_g_for_100g",
    "Glucose (g/100 g)": "glucose_in_g_for_100g",
    "Lactose (g/100 g)": "lactose_in_g_for_100g",
    "Maltose (g/100 g)": "maltose_in_g_for_100g",
    "Saccharose (g/100 g)": "sucrose_in_g_for_100g",
    "Amidon (g/100 g)": "starch_in_g_for_100g",
    "Fibres alimentaires (g/100 g)": "dietary_fibers_in_g_for_100g",
    "Polyols totaux (g/100 g)": "total_polyols_in_g_for_100g"
})


# Store the Fats
fats_df = nutrition_cleaned_df[[
    "alim_nom_fr",
    "AG saturés (g/100 g)",
    "AG monoinsaturés (g/100 g)",
    "AG polyinsaturés (g/100 g)",
    "AG 4:0, butyrique (g/100 g)",
    "AG 6:0, caproïque (g/100 g)",
    "AG 8:0, caprylique (g/100 g)",
    "AG 10:0, caprique (g/100 g)",
    "AG 12:0, laurique (g/100 g)",
    "AG 14:0, myristique (g/100 g)",
    "AG 16:0, palmitique (g/100 g)",
    "AG 18:0, stéarique (g/100 g)",
    "AG 18:1 9c (n-9), oléique (g/100 g)",
    "AG 18:2 9c,12c (n-6), linoléique (g/100 g)",
    "AG 18:3 c9,c12,c15 (n-3), alpha-linolénique (g/100 g)",
    "AG 20:4 5c,8c,11c,14c (n-6), arachidonique (g/100 g)",
    "AG 20:5 5c,8c,11c,14c,17c (n-3) EPA (g/100 g)",
    "AG 22:6 4c,7c,10c,13c,16c,19c (n-3) DHA (g/100 g)",
    "Cholestérol (mg/100 g)"
]]
fats_df = fats_df.rename(columns = {
    "alim_nom_fr": "food_name_in_french",
    "AG saturés (g/100 g)": "saturated_fats_in_g_for_100g",
    "AG monoinsaturés (g/100 g)": "monounsaturated_fats_in_g_for_100g",
    "AG polyinsaturés (g/100 g)": "polyunsaturated_fats_in_g_for_100g",
    "AG 4:0, butyrique (g/100 g)": "butyric_acid_4_0_in_g_for_100g",
    "AG 6:0, caproïque (g/100 g)": "caproic_acid_6_0_in_g_for_100g",
    "AG 8:0, caprylique (g/100 g)": "caprylic_acid_8_0_in_g_for_100g",
    "AG 10:0, caprique (g/100 g)": "capric_acid_10_0_in_g_for_100g",
    "AG 12:0, laurique (g/100 g)": "lauric_acid_12_0_in_g_for_100g",
    "AG 14:0, myristique (g/100 g)": "myristic_acid_14_0_in_g_for_100g",
    "AG 16:0, palmitique (g/100 g)": "palmitic_acid_16_0_in_g_for_100g",
    "AG 18:0, stéarique (g/100 g)": "stearic_acid_18_0_in_g_for_100g",
    "AG 18:1 9c (n-9), oléique (g/100 g)": "oleic_acid_18_1_n_9_in_g_for_100g",
    "AG 18:2 9c,12c (n-6), linoléique (g/100 g)": "linoleic_acid_18_2_n_6_in_g_for_100g",
    "AG 18:3 c9,c12,c15 (n-3), alpha-linolénique (g/100 g)": "alpha_linolenic_acid_18_3_n_3_in_g_for_100g",
    "AG 20:4 5c,8c,11c,14c (n-6), arachidonique (g/100 g)": "arachidonic_acid_20_4_n_6_in_g_for_100g",
    "AG 20:5 5c,8c,11c,14c,17c (n-3) EPA (g/100 g)": "eicosapentaenoic_acid_20_5_n_3_in_g_for_100g",
    "AG 22:6 4c,7c,10c,13c,16c,19c (n-3) DHA (g/100 g)": "docosahexaenoic_acid_22_6_n_3_in_g_for_100g",
    "Cholestérol (mg/100 g)": "cholesterol_in_mg_for_100g"
})


# Store the Minerals
minerals_df = nutrition_cleaned_df[[
    "alim_nom_fr",
    "Sel chlorure de sodium (g/100 g)",
    "Calcium (mg/100 g)",
    "Chlorure (mg/100 g)",
    "Cuivre (mg/100 g)",
    "Fer (mg/100 g)",
    "Iode (µg/100 g)",
    "Magnésium (mg/100 g)",
    "Manganèse (mg/100 g)",
    "Phosphore (mg/100 g)",
    "Potassium (mg/100 g)",
    "Sélénium (µg/100 g)",
    "Sodium (mg/100 g)",
    "Zinc (mg/100 g)"
]]
minerals_df = minerals_df.rename(columns = {
    "alim_nom_fr": "food_name_in_french",
    "Sel chlorure de sodium (g/100 g)": "sodium_chloride_in_g_for_100g",
    "Calcium (mg/100 g)": "calcium_in_mg_for_100g",
    "Chlorure (mg/100 g)": "chloride_in_mg_for_100g",
    "Cuivre (mg/100 g)": "copper_in_mg_for_100g",
    "Fer (mg/100 g)": "iron_in_mg_for_100g",
    "Iode (µg/100 g)": "iodine_in_µg_for_100g",
    "Magnésium (mg/100 g)": "magnesium_in_mg_for_100g",
    "Manganèse (mg/100 g)": "manganese_in_mg_for_100g",
    "Phosphore (mg/100 g)": "phosphorus_in_mg_for_100g",
    "Potassium (mg/100 g)": "potassium_in_mg_for_100g",
    "Sélénium (µg/100 g)": "selenium_in_µg_for_100g",
    "Sodium (mg/100 g)": "sodium_in_mg_for_100g",
    "Zinc (mg/100 g)": "zinc_in_mg_for_100g"
})


# Store the Vitamins
vitamins_df = nutrition_cleaned_df[[
    "alim_nom_fr",
    "Rétinol (µg/100 g)",
    "Beta-Carotène (µg/100 g)",
    "Vitamine D (µg/100 g)",
    "Vitamine E (mg/100 g)",
    "Vitamine K1 (µg/100 g)",
    "Vitamine K2 (µg/100 g)",
    "Vitamine C (mg/100 g)",
    "Vitamine B1 ou Thiamine (mg/100 g)",
    "Vitamine B2 ou Riboflavine (mg/100 g)",
    "Vitamine B3 ou PP ou Niacine (mg/100 g)",
    "Vitamine B5 ou Acide pantothénique (mg/100 g)",
    "Vitamine B6 (mg/100 g)",
    "Vitamine B9 ou Folates totaux (µg/100 g)",
    "Vitamine B12 (µg/100 g)"
]]
vitamins_df = vitamins_df.rename(columns = {
    "alim_nom_fr": "food_name_in_french",
    "Rétinol (µg/100 g)": "retinol_in_µg_for_100g",
    "Beta-Carotène (µg/100 g)": "beta_carotene_in_µg_for_100g",
    "Vitamine D (µg/100 g)": "vitamin_d_in_µg_for_100g",
    "Vitamine E (mg/100 g)": "vitamin_e_in_mg_for_100g",
    "Vitamine K1 (µg/100 g)": "vitamin_k1_in_µg_for_100g",
    "Vitamine K2 (µg/100 g)": "vitamin_k2_in_µg_for_100g",
    "Vitamine C (mg/100 g)": "vitamin_c_in_mg_for_100g",
    "Vitamine B1 ou Thiamine (mg/100 g)": "vitamin_b1_thiamine_in_mg_for_100g",
    "Vitamine B2 ou Riboflavine (mg/100 g)": "vitamin_b2_riboflavin_in_mg_for_100g",
    "Vitamine B3 ou PP ou Niacine (mg/100 g)": "vitamin_b3_niacin_in_mg_for_100g",
    "Vitamine B5 ou Acide pantothénique (mg/100 g)": "vitamin_b5_pantothenic_acid_in_mg_for_100g",
    "Vitamine B6 (mg/100 g)": "vitamin_b6_in_mg_for_100g",
    "Vitamine B9 ou Folates totaux (µg/100 g)": "vitamin_b9_total_folate_in_µg_for_100g",
    "Vitamine B12 (µg/100 g)": "vitamin_b12_in_µg_for_100g"
})


# Store the Additional contents
additional_nutrition_data_df = nutrition_cleaned_df[[
    "alim_nom_fr",
    "Cendres (g/100 g)",
    "Alcool (g/100 g)",
    "Acides organiques (g/100 g)"
]]
additional_nutrition_data_df = additional_nutrition_data_df.rename(columns = {
    "alim_nom_fr": "food_name_in_french",
    "Cendres (g/100 g)": "ashes_in_g_for_100g",
    "Alcool (g/100 g)": "alcohol_in_g_for_100g",
    "Acides organiques (g/100 g)": "organic_acids_in_g_for_100g"
})

# %%
# Convert dataframes to CSV files
dataframes_dict = {
    "macro_nutrients_df": macro_nutrients_df,
    "carbs_df": carbs_df,
    "fats_df": fats_df,
    "minerals_df": minerals_df,
    "vitamins_df": vitamins_df,
    "additional_nutrition_data_df": additional_nutrition_data_df
}
csv_filenames = {
    "macro_nutrients_df": "macro_nutrients_csv.csv",
    "carbs_df": "carbohydrates_csv.csv",
    "fats_df": "fats_csv.csv",
    "minerals_df": "minerals_csv.csv",
    "vitamins_df": "vitamins_csv.csv",
    "additional_nutrition_data_df": "additional_nutrition_data_csv.csv"
}

for key, dataframe in dataframes_dict.items():
    csv_filename = csv_filenames[key]
    dataframe_to_file(dataframe, csv_filename, "csv")
# Out:
# Creation of 'macro_nutrients_csv.csv' successful
# Creation of 'carbohydrates_csv.csv' successful
# Creation of 'fats_csv.csv' successful
# Creation of 'minerals_csv.csv' successful
# Creation of 'vitamins_csv.csv' successful
# Creation of 'additional_nutrition_data_csv.csv' successful

# %% [markdown]
# <ul>
#     <li>Descriptive Statistics
#         <ul>
#             <li>Range (3.6): Indicates moderate variability in the dataset, showing a reasonable spread between the minimum (4.2) and maximum (7.8) values (the data spans 3.6 units).</li>
#             <li>Minimum value (4.2): The lowest value in the dataset, indicating the lower limit of sepal length.</li>
#             <li>Q1 (5.1): Represents the first quartile, meaning that 25% of the values fall below 5.1, highlighting the lower end of the data distribution.</li>
#             <li>Median (5.8): The median indicates that 50% of the values are below 5.8, serving as a measure of central tendency that is less affected by extreme values.</li>
#             <li>Q3 (6.4): The third quartile indicates that 75% of the values fall below 6.4, marking the upper end of the middle 50% of the data.</li>
#             <li>Maximum value (7.8): The highest value in the dataset, indicating the upper limit of sepal length.</li>
#             <li>IQR (1.3): The interquartile range shows that the middle 50% of the values are grouped between 5.1 and 6.4, indicating moderate variability in this central range.</li>
#             <li>Mean (5.84): The mean is slightly higher than the median, suggesting a potential right skew in the distribution due to the presence of a few higher values.</li>
#             <li>Standard deviation (0.83): Indicates moderate dispersion from the mean, suggesting that data points are reasonably spread around the average value.</li>
#         </ul>
#     </li>
#     <br>
#     <li>Distribution Characteristics
#         <ul>
#             <li>Mode(s) (5.0): The mode, being 5.0, is the most frequently occurring value in the dataset, suggesting a concentration of observations around this value.</li>
#             <li>Skewness (0.31): A skewness value of 0.31 indicates a slight positive skew, suggesting that a few higher values are affecting the overall shape of the distribution.</li>
#             <li>Lower bound (3.15): Values below 3.15 are flagged as potential outliers, indicating unusually low observations compared to the overall dataset.</li>
#             <li>Upper bound (8.35): Values above 8.35 are considered potential outliers, highlighting unusually high observations that could influence analysis.</li>
#             <li>Outlier (No outliers) and Outliers count (0): No outliers detected, indicating a clean dataset.</li>
#             <li>Unique values count (35): The presence of 35 unique values indicates a diverse dataset, enhancing the richness and reliability of statistical analysis.</li>
#         </ul>
#     </li>
# </ul>

# %% [markdown]
# <ul>
#     <li>Very strong positive correlations
#         <ul>
#             <li>Petal length tends to increase with its width</li>
#             <li>Petal length tends to increase with its sepal length</li>
#             <li>Petal width tends to increase with its sepal length</li>
#         </ul>
#     </li>
#     <br>
#     <li>Very strong negative correlations
#         <ul>
#             <li>No correlations</li>
#         </ul>
#     </li>
#     <br>
#     <li>Strong positive correlations
#         <ul>
#             <li>No correlations</li>
#         </ul>
#     </li>
#     <br>
#     <li>Strong negative correlations
#         <ul>
#             <li>No correlations</li>
#         </ul>
#     </li>
# </ul>
